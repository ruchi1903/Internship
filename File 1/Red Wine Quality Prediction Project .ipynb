# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Red%20Wine/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: chlorides, Length: 153, dtype: int64
#
#
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 29.0     23
# 28.0     23
# 22.0     22
# 32.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 36.0     11
# 33.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 45.0      3
# 1.0       3
# 43.0      3
# 42.0      3
# 52.0      3
# 37.0      3
# 68.0      2
# 55.0      2
# 50.0      2
# 37.5      2
# 53.0      1
# 72.0      1
# 57.0      1
# 47.0      1
# 5.5       1
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: free sulfur dioxide, dtype: int64
#
#
# 28.0     43
# 24.0     36
# 15.0     35
# 18.0     35
# 23.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: total sulfur dioxide, Length: 144, dtype: int64
#
#
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: density, Length: 436, dtype: int64
#
#
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64
#
#
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: sulphates, Length: 96, dtype: int64
#
#
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: alcohol, Length: 65, dtype: int64
#
#
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(10,7))
sns.countplot(x ='quality', data = df)
plt.xlabel('Quality of Red Wine')
plt.ylabel('Count of Rows in the dataset')
plt.show()

# %%
index=0
labels = df['quality']
features = df.drop('quality', axis=1)

for col in features.items():
    plt.figure(figsize=(10,5))
    sns.barplot(x=labels, y=col[index], data=df, color="deeppink")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(15,10))
index = 0
ax = ax.flatten()
for col, value in df.items():
    sns.boxplot(y=col, data=df, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(15,10))
index = 0
ax = ax.flatten()
for col, value in df.items():
    sns.distplot(value, ax=ax[index], hist=False, color="g", kde_kws={"shade": True})
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
# !pip install imblearn
from sklearn.preprocessing import OrdinalEncoder
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: imbalanced-learn in ./anaconda3/lib/python3.10/site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scipy>=1.3.2 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.1.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: numpy>=1.17.3 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
lower_triangle = np.tril(df.corr())
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), linewidths = 0.1,linecolor = "black", annot=True, fmt='0.3f', cmap="Blues_r")
plt.yticks(rotation = 0)
plt.show()

# %%
df = df.drop('free sulfur dioxide', axis=1)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# 1                     67.0  0.99680  3.20       0.68      9.8        5
# 2                     54.0  0.99700  3.26       0.65      9.8        5
# 3                     60.0  0.99800  3.16       0.58      9.8        6
# 4                     34.0  0.99780  3.51       0.56      9.4        5
# ...                    ...      ...   ...        ...      ...      ...
# 1594                  44.0  0.99490  3.45       0.58     10.5        5
# 1595                  51.0  0.99512  3.52       0.76     11.2        6
# 1596                  40.0  0.99574  3.42       0.75     11.0        6
# 1597                  44.0  0.99547  3.57       0.71     10.2        5
# 1598                  42.0  0.99549  3.39       0.66     11.0        6
#
# [1599 rows x 11 columns]

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)

df=df[(z<3).all(axis=1)]
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# 1                     67.0  0.99680  3.20       0.68      9.8        5
# 2                     54.0  0.99700  3.26       0.65      9.8        5
# 3                     60.0  0.99800  3.16       0.58      9.8        6
# 4                     34.0  0.99780  3.51       0.56      9.4        5
# ...                    ...      ...   ...        ...      ...      ...
# 1594                  44.0  0.99490  3.45       0.58     10.5        5
# 1595                  51.0  0.99512  3.52       0.76     11.2        6
# 1596                  40.0  0.99574  3.42       0.75     11.0        6
# 1597                  44.0  0.99547  3.57       0.71     10.2        5
# 1598                  42.0  0.99549  3.39       0.66     11.0        6
#
# [1464 rows x 11 columns]

# %%
data_loss=(1599-1464)/1599*100 
data_loss
# Out:
# 8.442776735459661

# %%
X = df.drop('quality', axis=1)
Y = df['quality']

# %%
Y.value_counts()
# Out:
# 5    624
# 6    590
# 7    187
# 4     47
# 8     16
# Name: quality, dtype: int64

# %%
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 5    624
# 6    624
# 7    624
# 4    624
# 8    624
# Name: quality, dtype: int64

# %%
Y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 3115    8
# 3116    8
# 3117    8
# 3118    8
# 3119    8
# Name: quality, Length: 3120, dtype: int64

# %%
Y = Y.apply(lambda y_value:1 if y_value>=7 else 0) # 1 is for good quality and 0 for bad (not good) quality
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3115    1
# 3116    1
# 3117    1
# 3118    1
# 3119    1
# Name: quality, Length: 3120, dtype: int64

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 3115       9.662955          0.307493     0.471059        1.961281   0.080242
# 3116       9.885795          0.375444     0.514734        2.192897   0.070509
# 3117       7.419334          0.449456     0.229578        2.109667   0.059290
# 3118       8.803225          0.453548     0.433126        3.023324   0.078318
# 3119       9.380613          0.300264     0.557973        2.790307   0.079833
#
#       total sulfur dioxide   density        pH  sulphates    alcohol
# 0                34.000000  0.997800  3.510000   0.560000   9.400000
# 1                67.000000  0.996800  3.200000   0.680000   9.800000
# 2                54.000000  0.997000  3.260000   0.650000   9.800000
# 3                60.000000  0.998000  3.160000   0.580000   9.800000
# 4                34.000000  0.997800  3.510000   0.560000   9.400000
# ...                    ...       ...       ...        ...        ...
# 3115             69.557135  0.994458  3.053537   0.646852  11.937882
# 3116             16.000000  0.995887  3.180533   0.670355  11.763317
# 3117             34.848894  0.994519  3.314078   0.752689  11.811778
# 3118             22.200994  0.995849  3.232804   0.696402  12.119602
# 3119             16.964752  0.996396  3.150705   0.921586  11.685019
#
# [3120 rows x 10 columns]

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.660985          1.066809    -1.507990       -0.634198  -0.154451
# 1         -0.407183          2.088732    -1.507990        0.159988   1.052931
# 2         -0.407183          1.407450    -1.303148       -0.180377   0.723645
# 3          1.750137         -1.317677     1.359802       -0.634198  -0.209332
# 4         -0.660985          1.066809    -1.507990       -0.634198  -0.154451
# ...             ...               ...          ...             ...        ...
# 3115       0.774873         -1.161592     0.904330       -0.564671   0.078374
# 3116       0.916266         -0.775809     1.127991       -0.301890  -0.455809
# 3117      -0.648718         -0.355619    -0.332310       -0.396320  -1.071512
# 3118       0.229369         -0.332383     0.710076        0.640271  -0.027258
# 3119       0.595725         -1.202629     1.349423        0.375901   0.055885
#
#       total sulfur dioxide   density        pH  sulphates   alcohol
# 0                -0.100360  0.860290  1.466190  -0.812542 -1.256355
# 1                 1.155673  0.245616 -0.756101   0.091241 -0.899777
# 2                 0.660872  0.368551 -0.325981  -0.134705 -0.899777
# 3                 0.889241  0.983224 -1.042849  -0.661912 -0.899777
# 4                -0.100360  0.860290  1.466190  -0.812542 -1.256355
# ...                    ...       ...       ...        ...       ...
# 3115              1.253001 -1.194003 -1.806048  -0.158412  1.006024
# 3116             -0.785469 -0.315522 -0.895656   0.018601  0.850409
# 3117             -0.068050 -1.156488  0.061686   0.638700  0.893609
# 3118             -0.549449 -0.339132 -0.520940   0.214773  1.168017
# 3119             -0.748749 -0.002419 -1.109482   1.910755  0.780611
#
# [3120 rows x 10 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)

# %%
def classify(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # Accuracy Score
    acc_score = (accuracy_score(Y_test, pred))*100
    print("Accuracy Score:", acc_score)
    
    # Classification Report
    class_report = classification_report(Y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of accuracy minus cv scores
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %%
model=LogisticRegression()
classify(model, X, Y)
# Out:
# Accuracy Score: 89.90384615384616
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       391
#            1       0.86      0.88      0.87       233
#
#     accuracy                           0.90       624
#    macro avg       0.89      0.89      0.89       624
# weighted avg       0.90      0.90      0.90       624
#
# Cross Validation Score: 87.88461538461539
#
# Accuracy Score - Cross Validation Score is 2.0192307692307736

# %%
model=SVC(C=1.0, kernel='rbf', gamma='auto', random_state=42)
classify(model, X, Y)
# Out:
# Accuracy Score: 92.78846153846155
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       391
#            1       0.89      0.92      0.90       233
#
#     accuracy                           0.93       624
#    macro avg       0.92      0.93      0.92       624
# weighted avg       0.93      0.93      0.93       624
#
# Cross Validation Score: 89.71153846153847
#
# Accuracy Score - Cross Validation Score is 3.07692307692308

# %%
model=DecisionTreeClassifier(random_state=21, max_depth=15)
classify(model, X, Y)
# Out:
# Accuracy Score: 93.75
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       391
#            1       0.90      0.94      0.92       233
#
#     accuracy                           0.94       624
#    macro avg       0.93      0.94      0.93       624
# weighted avg       0.94      0.94      0.94       624
#
# Cross Validation Score: 89.61538461538461
#
# Accuracy Score - Cross Validation Score is 4.134615384615387

# %%
model=RandomForestClassifier(max_depth=15, random_state=111)
classify(model, X, Y)
# Out:
# Accuracy Score: 96.15384615384616
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       391
#            1       0.93      0.97      0.95       233
#
#     accuracy                           0.96       624
#    macro avg       0.96      0.96      0.96       624
# weighted avg       0.96      0.96      0.96       624
#
# Cross Validation Score: 92.88461538461539
#
# Accuracy Score - Cross Validation Score is 3.2692307692307736

# %%
model=KNeighborsClassifier(n_neighbors=15)
classify(model, X, Y)
# Out:
# Accuracy Score: 91.50641025641025
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93       391
#            1       0.85      0.93      0.89       233
#
#     accuracy                           0.92       624
#    macro avg       0.91      0.92      0.91       624
# weighted avg       0.92      0.92      0.92       624
#
# Cross Validation Score: 88.7179487179487
#
# Accuracy Score - Cross Validation Score is 2.788461538461547

# %%
model=ExtraTreesClassifier()
classify(model, X, Y)
# Out:
# Accuracy Score: 96.31410256410257
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       391
#            1       0.93      0.97      0.95       233
#
#     accuracy                           0.96       624
#    macro avg       0.96      0.96      0.96       624
# weighted avg       0.96      0.96      0.96       624
#
# Cross Validation Score: 93.68589743589745
#
# Accuracy Score - Cross Validation Score is 2.628205128205124

# %%
svc_param = {'kernel' : ['poly', 'sigmoid', 'rbf'],
             'gamma' : ['scale', 'auto'],
             'shrinking' : [True, False],
             'random_state' : [21,42,104],
             'probability' : [True, False],
             'decision_function_shape' : ['ovo', 'ovr'],
             'verbose' : [True, False]}

# %%
GSCV = GridSearchCV(SVC(), svc_param, cv=5)

# %%
GSCV.fit(X_train,Y_train)
# Out:
# [LibSVM].*.*
# optimization finished, #iter = 2238
# obj = -465.187183, rho = 0.508896
# nSV = 590, nBSV = 499
# Total nSV = 590
# .
# Warning: using -h 0 may be faster
# *..*.*
# optimization finished, #iter = 3628
# obj = -439.108275, rho = 0.577843
# nSV = 566, nBSV = 480
# Total nSV = 566
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2029
# obj = -445.043231, rho = 0.588638
# nSV = 569, nBSV = 491
# Total nSV = 569
# .*
# optimization finished, #iter = 1821
# obj = -423.106311, rho = 0.567780
# nSV = 541, nBSV = 463
# Total nSV = 541
# .
# Warning: using -h 0 may be faster
# *.*.*
# optimization finished, #iter = 3048
# obj = -443.067358, rho = 0.549950
# nSV = 569, nBSV = 490
# Total nSV = 569
# ..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4010
# obj = -541.621442, rho = -0.578932
# nSV = 678, nBSV = 590
# Total nSV = 678
# [LibSVM].*.*
# optimization finished, #iter = 2257
# obj = -467.294149, rho = 0.522487
# nSV = 593, nBSV = 508
# Total nSV = 593
# .*
# optimization finished, #iter = 1994
# obj = -433.051373, rho = 0.577344
# nSV = 559, nBSV = 474
# Total nSV = 559
# .*.*
# optimization finished, #iter = 2088
# obj = -434.182286, rho = 0.526189
# nSV = 550, nBSV = 470
# Total nSV = 550
# .*.*
# optimization finished, #iter = 2004
# obj = -454.354943, rho = 0.571955
# nSV = 583, nBSV = 499
# Total nSV = 583
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2647
# obj = -427.798772, rho = 0.552164
# nSV = 554, nBSV = 461
# Total nSV = 554
# ..*.*
# optimization finished, #iter = 3947
# obj = -542.336741, rho = -0.556944
# nSV = 685, nBSV = 584
# Total nSV = 685
# [LibSVM].*
# optimization finished, #iter = 1760
# obj = -467.124152, rho = 0.509731
# nSV = 585, nBSV = 508
# Total nSV = 585
# .*
# optimization finished, #iter = 1467
# obj = -435.810513, rho = 0.554088
# nSV = 555, nBSV = 482
# Total nSV = 555
# .*.*
# optimization finished, #iter = 2364
# obj = -447.960995, rho = 0.517529
# nSV = 570, nBSV = 484
# Total nSV = 570
# .*
# optimization finished, #iter = 1505
# obj = -457.841289, rho = 0.541902
# nSV = 580, nBSV = 506
# Total nSV = 580
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2072
# obj = -422.461113, rho = 0.538664
# nSV = 543, nBSV = 461
# Total nSV = 543
# ..*.*
# optimization finished, #iter = 3228
# obj = -547.005282, rho = -0.533269
# nSV = 684, nBSV = 589
# Total nSV = 684
# [LibSVM].*
# optimization finished, #iter = 1315
# obj = -450.783782, rho = 0.517817
# nSV = 568, nBSV = 497
# Total nSV = 568
# .*.*
# optimization finished, #iter = 2403
# obj = -435.003203, rho = 0.521500
# nSV = 563, nBSV = 472
# Total nSV = 563
# ..*
# optimization finished, #iter = 2706
# obj = -438.556505, rho = 0.532419
# nSV = 555, nBSV = 481
# Total nSV = 555
# .*.*
# optimization finished, #iter = 2184
# obj = -445.379895, rho = 0.543453
# nSV = 559, nBSV = 484
# Total nSV = 559
# .*
# optimization finished, #iter = 1989
# obj = -423.210446, rho = 0.543458
# nSV = 538, nBSV = 458
# Total nSV = 538
# ..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4061
# obj = -537.626835, rho = -0.548593
# nSV = 678, nBSV = 583
# Total nSV = 678
# [LibSVM].*
# optimization finished, #iter = 1769
# obj = -437.105659, rho = 0.540506
# nSV = 562, nBSV = 482
# Total nSV = 562
# .*.*
# optimization finished, #iter = 2406
# obj = -409.751619, rho = 0.513055
# nSV = 532, nBSV = 444
# Total nSV = 532
# .*.*
# optimization finished, #iter = 2007
# obj = -417.188206, rho = 0.527305
# nSV = 541, nBSV = 458
# Total nSV = 541
# .*.*
# optimization finished, #iter = 2210
# obj = -425.867728, rho = 0.542802
# nSV = 554, nBSV = 477
# Total nSV = 554
# .*.*
# optimization finished, #iter = 2082
# obj = -402.165669, rho = 0.577418
# nSV = 522, nBSV = 444
# Total nSV = 522
# ..*
# optimization finished, #iter = 2580
# obj = -510.959148, rho = -0.550986
# nSV = 643, nBSV = 560
# Total nSV = 643
# [LibSVM]..*
# optimization finished, #iter = 2230
# obj = -465.187185, rho = 0.508881
# nSV = 586, nBSV = 501
# Total nSV = 586
# ..*
# optimization finished, #iter = 2500
# obj = -439.108275, rho = 0.577830
# nSV = 563, nBSV = 481
# Total nSV = 563
# .*
# optimization finished, #iter = 1997
# obj = -445.043230, rho = 0.588664
# nSV = 565, nBSV = 492
# Total nSV = 565
# .*
# optimization finished, #iter = 1799
# obj = -423.106310, rho = 0.567799
# nSV = 536, nBSV = 462
# Total nSV = 536
# ..*
# optimization finished, #iter = 2482
# obj = -443.067356, rho = 0.549986
# nSV = 565, nBSV = 491
# Total nSV = 565
# ..*
# optimization finished, #iter = 2827
# obj = -541.621438, rho = -0.578940
# nSV = 674, nBSV = 591
# Total nSV = 674
# [LibSVM]..*
# optimization finished, #iter = 2287
# obj = -467.294150, rho = 0.522489
# nSV = 588, nBSV = 508
# Total nSV = 588
# ..*
# optimization finished, #iter = 2001
# obj = -433.051371, rho = 0.577338
# nSV = 555, nBSV = 475
# Total nSV = 555
# ..*
# optimization finished, #iter = 2121
# obj = -434.182288, rho = 0.526147
# nSV = 548, nBSV = 469
# Total nSV = 548
# ..*
# optimization finished, #iter = 2004
# obj = -454.354943, rho = 0.571947
# nSV = 578, nBSV = 499
# Total nSV = 578
# ..*
# optimization finished, #iter = 2693
# obj = -427.798774, rho = 0.552153
# nSV = 550, nBSV = 464
# Total nSV = 550
# ...*
# optimization finished, #iter = 3590
# obj = -542.336748, rho = -0.557010
# nSV = 678, nBSV = 584
# Total nSV = 678
# [LibSVM].*
# optimization finished, #iter = 1787
# obj = -467.124152, rho = 0.509686
# nSV = 582, nBSV = 509
# Total nSV = 582
# .*
# optimization finished, #iter = 1445
# obj = -435.810512, rho = 0.554100
# nSV = 549, nBSV = 481
# Total nSV = 549
# ..*
# optimization finished, #iter = 2453
# obj = -447.961002, rho = 0.517503
# nSV = 567, nBSV = 483
# Total nSV = 567
# .*
# optimization finished, #iter = 1506
# obj = -457.841289, rho = 0.541867
# nSV = 574, nBSV = 507
# Total nSV = 574
# ..*
# optimization finished, #iter = 2105
# obj = -422.461113, rho = 0.538667
# nSV = 540, nBSV = 461
# Total nSV = 540
# ..*
# optimization finished, #iter = 2827
# obj = -547.005285, rho = -0.533303
# nSV = 679, nBSV = 589
# Total nSV = 679
# [LibSVM].*
# optimization finished, #iter = 1382
# obj = -450.783784, rho = 0.517768
# nSV = 565, nBSV = 498
# Total nSV = 565
# ..*
# optimization finished, #iter = 2422
# obj = -435.003204, rho = 0.521472
# nSV = 557, nBSV = 473
# Total nSV = 557
# ..*
# optimization finished, #iter = 2665
# obj = -438.556504, rho = 0.532413
# nSV = 552, nBSV = 481
# Total nSV = 552
# ..*
# optimization finished, #iter = 2304
# obj = -445.379899, rho = 0.543421
# nSV = 555, nBSV = 485
# Total nSV = 555
# .*
# optimization finished, #iter = 1956
# obj = -423.210445, rho = 0.543438
# nSV = 533, nBSV = 460
# Total nSV = 533
# ..*
# optimization finished, #iter = 2603
# obj = -537.626832, rho = -0.548601
# nSV = 671, nBSV = 582
# Total nSV = 671
# [LibSVM].*
# optimization finished, #iter = 1767
# obj = -437.105659, rho = 0.540486
# nSV = 560, nBSV = 484
# Total nSV = 560
# ..*
# optimization finished, #iter = 2356
# obj = -409.751615, rho = 0.513060
# nSV = 529, nBSV = 445
# Total nSV = 529
# ..*
# optimization finished, #iter = 2023
# obj = -417.188206, rho = 0.527337
# nSV = 539, nBSV = 458
# Total nSV = 539
# ..*
# optimization finished, #iter = 2233
# obj = -425.867731, rho = 0.542801
# nSV = 550, nBSV = 477
# Total nSV = 550
# ..*
# optimization finished, #iter = 2170
# obj = -402.165673, rho = 0.577397
# nSV = 520, nBSV = 444
# Total nSV = 520
# ..*
# optimization finished, #iter = 2615
# obj = -510.959148, rho = -0.551041
# nSV = 640, nBSV = 561
# Total nSV = 640
# [LibSVM].*.*
# optimization finished, #iter = 2432
# obj = -454.987223, rho = 0.577841
# nSV = 585, nBSV = 500
# Total nSV = 585
# .*
# optimization finished, #iter = 1795
# obj = -433.674293, rho = 0.553466
# nSV = 559, nBSV = 476
# Total nSV = 559
# ..*.*.*
# optimization finished, #iter = 4080
# obj = -442.013012, rho = 0.568525
# nSV = 574, nBSV = 486
# Total nSV = 574
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1817
# obj = -433.988957, rho = 0.570462
# nSV = 559, nBSV = 482
# Total nSV = 559
# .*
# optimization finished, #iter = 1710
# obj = -448.433378, rho = 0.541777
# nSV = 569, nBSV = 482
# Total nSV = 569
# ..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4010
# obj = -541.621442, rho = -0.578932
# nSV = 678, nBSV = 590
# Total nSV = 678
# [LibSVM].*.*
# optimization finished, #iter = 2115
# obj = -453.731380, rho = 0.536914
# nSV = 580, nBSV = 500
# Total nSV = 580
# .*
# optimization finished, #iter = 1598
# obj = -436.642002, rho = 0.497882
# nSV = 554, nBSV = 484
# Total nSV = 554
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2170
# obj = -458.170395, rho = 0.543281
# nSV = 585, nBSV = 502
# Total nSV = 585
# .**.*
# optimization finished, #iter = 1914
# obj = -416.754823, rho = 0.603666
# nSV = 539, nBSV = 460
# Total nSV = 539
# ..*
# optimization finished, #iter = 2484
# obj = -446.474764, rho = 0.548975
# nSV = 575, nBSV = 485
# Total nSV = 575
# ..*.*
# optimization finished, #iter = 3947
# obj = -542.336741, rho = -0.556944
# nSV = 685, nBSV = 584
# Total nSV = 685
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2006
# obj = -449.649663, rho = 0.506120
# nSV = 568, nBSV = 500
# Total nSV = 568
# .*.*
# optimization finished, #iter = 1922
# obj = -440.223076, rho = 0.498021
# nSV = 552, nBSV = 479
# Total nSV = 552
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1824
# obj = -454.022435, rho = 0.520399
# nSV = 578, nBSV = 502
# Total nSV = 578
# .*
# optimization finished, #iter = 1888
# obj = -437.975270, rho = 0.567877
# nSV = 560, nBSV = 479
# Total nSV = 560
# .*.*
# optimization finished, #iter = 2259
# obj = -450.397833, rho = 0.557562
# nSV = 577, nBSV = 489
# Total nSV = 577
# ..*.*
# optimization finished, #iter = 3228
# obj = -547.005282, rho = -0.533269
# nSV = 684, nBSV = 589
# Total nSV = 684
# [LibSVM].**.*
# optimization finished, #iter = 2017
# obj = -444.221348, rho = 0.510447
# nSV = 557, nBSV = 479
# Total nSV = 557
# .*.*
# optimization finished, #iter = 2305
# obj = -440.192800, rho = 0.486918
# nSV = 569, nBSV = 478
# Total nSV = 569
# .*.*
# optimization finished, #iter = 2119
# obj = -435.203017, rho = 0.518972
# nSV = 560, nBSV = 478
# Total nSV = 560
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1750
# obj = -437.546916, rho = 0.589256
# nSV = 555, nBSV = 477
# Total nSV = 555
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2148
# obj = -435.142028, rho = 0.586584
# nSV = 553, nBSV = 470
# Total nSV = 553
# ..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4061
# obj = -537.626835, rho = -0.548593
# nSV = 678, nBSV = 583
# Total nSV = 678
# [LibSVM].*.*
# optimization finished, #iter = 2182
# obj = -413.821945, rho = 0.496137
# nSV = 536, nBSV = 451
# Total nSV = 536
# .*
# optimization finished, #iter = 1575
# obj = -423.516759, rho = 0.533109
# nSV = 537, nBSV = 463
# Total nSV = 537
# .*
# optimization finished, #iter = 1689
# obj = -404.726976, rho = 0.523736
# nSV = 531, nBSV = 456
# Total nSV = 531
# .*.*
# optimization finished, #iter = 2216
# obj = -430.779425, rho = 0.582652
# nSV = 554, nBSV = 470
# Total nSV = 554
# .*
# optimization finished, #iter = 1873
# obj = -420.917987, rho = 0.553507
# nSV = 544, nBSV = 461
# Total nSV = 544
# ..*
# optimization finished, #iter = 2580
# obj = -510.959148, rho = -0.550986
# nSV = 643, nBSV = 560
# Total nSV = 643
# [LibSVM]..*
# optimization finished, #iter = 2423
# obj = -454.987222, rho = 0.577858
# nSV = 580, nBSV = 500
# Total nSV = 580
# .*
# optimization finished, #iter = 1851
# obj = -433.674295, rho = 0.553413
# nSV = 555, nBSV = 476
# Total nSV = 555
# ...*
# optimization finished, #iter = 3109
# obj = -442.013012, rho = 0.568519
# nSV = 567, nBSV = 485
# Total nSV = 567
# .*
# optimization finished, #iter = 1813
# obj = -433.988957, rho = 0.570419
# nSV = 555, nBSV = 481
# Total nSV = 555
# .*
# optimization finished, #iter = 1743
# obj = -448.433379, rho = 0.541759
# nSV = 563, nBSV = 481
# Total nSV = 563
# ..*
# optimization finished, #iter = 2827
# obj = -541.621438, rho = -0.578940
# nSV = 674, nBSV = 591
# Total nSV = 674
# [LibSVM]..*
# optimization finished, #iter = 2115
# obj = -453.731380, rho = 0.536913
# nSV = 577, nBSV = 498
# Total nSV = 577
# .*
# optimization finished, #iter = 1598
# obj = -436.642002, rho = 0.497876
# nSV = 552, nBSV = 482
# Total nSV = 552
# ..*
# optimization finished, #iter = 2122
# obj = -458.170393, rho = 0.543277
# nSV = 581, nBSV = 503
# Total nSV = 581
# .*
# optimization finished, #iter = 1796
# obj = -416.754823, rho = 0.603688
# nSV = 534, nBSV = 462
# Total nSV = 534
# ..*
# optimization finished, #iter = 2416
# obj = -446.474757, rho = 0.548997
# nSV = 571, nBSV = 486
# Total nSV = 571
# ...*
# optimization finished, #iter = 3590
# obj = -542.336748, rho = -0.557010
# nSV = 678, nBSV = 584
# Total nSV = 678
# [LibSVM].*
# optimization finished, #iter = 1989
# obj = -449.649662, rho = 0.506143
# nSV = 566, nBSV = 499
# Total nSV = 566
# .*
# optimization finished, #iter = 1884
# obj = -440.223079, rho = 0.497975
# nSV = 546, nBSV = 479
# Total nSV = 546
# .*
# optimization finished, #iter = 1794
# obj = -454.022434, rho = 0.520433
# nSV = 574, nBSV = 503
# Total nSV = 574
# .*
# optimization finished, #iter = 1941
# obj = -437.975274, rho = 0.567839
# nSV = 556, nBSV = 478
# Total nSV = 556
# ..*
# optimization finished, #iter = 2407
# obj = -450.397839, rho = 0.557494
# nSV = 572, nBSV = 489
# Total nSV = 572
# ..*
# optimization finished, #iter = 2827
# obj = -547.005285, rho = -0.533303
# nSV = 679, nBSV = 589
# Total nSV = 679
# [LibSVM].*
# optimization finished, #iter = 1988
# obj = -444.221347, rho = 0.510447
# nSV = 553, nBSV = 480
# Total nSV = 553
# ..*
# optimization finished, #iter = 2293
# obj = -440.192799, rho = 0.486915
# nSV = 561, nBSV = 477
# Total nSV = 561
# ..*
# optimization finished, #iter = 2185
# obj = -435.203019, rho = 0.518890
# nSV = 555, nBSV = 478
# Total nSV = 555
# .*
# optimization finished, #iter = 1754
# obj = -437.546915, rho = 0.589207
# nSV = 551, nBSV = 478
# Total nSV = 551
# ..*
# optimization finished, #iter = 2103
# obj = -435.142024, rho = 0.586627
# nSV = 551, nBSV = 468
# Total nSV = 551
# ..*
# optimization finished, #iter = 2603
# obj = -537.626832, rho = -0.548601
# nSV = 671, nBSV = 582
# Total nSV = 671
# [LibSVM]..*
# optimization finished, #iter = 2208
# obj = -413.821945, rho = 0.496125
# nSV = 533, nBSV = 453
# Total nSV = 533
# .*
# optimization finished, #iter = 1623
# obj = -423.516762, rho = 0.533052
# nSV = 535, nBSV = 463
# Total nSV = 535
# .*
# optimization finished, #iter = 1631
# obj = -404.726974, rho = 0.523711
# nSV = 527, nBSV = 455
# Total nSV = 527
# ..*
# optimization finished, #iter = 2216
# obj = -430.779425, rho = 0.582654
# nSV = 553, nBSV = 471
# Total nSV = 553
# .*
# optimization finished, #iter = 1869
# obj = -420.917986, rho = 0.553541
# nSV = 542, nBSV = 460
# Total nSV = 542
# ..*
# optimization finished, #iter = 2615
# obj = -510.959148, rho = -0.551041
# nSV = 640, nBSV = 561
# Total nSV = 640
# [LibSVM].*
# optimization finished, #iter = 1893
# obj = -431.512592, rho = 0.559948
# nSV = 550, nBSV = 468
# Total nSV = 550
# .*.*
# optimization finished, #iter = 2387
# obj = -463.981328, rho = 0.525834
# nSV = 596, nBSV = 510
# Total nSV = 596
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2547
# obj = -441.402481, rho = 0.552203
# nSV = 564, nBSV = 484
# Total nSV = 564
# ..*
# optimization finished, #iter = 2580
# obj = -446.628944, rho = 0.587082
# nSV = 576, nBSV = 492
# Total nSV = 576
# ..*.*
# optimization finished, #iter = 3080
# obj = -431.706215, rho = 0.574198
# nSV = 559, nBSV = 475
# Total nSV = 559
# ..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4010
# obj = -541.621442, rho = -0.578932
# nSV = 678, nBSV = 590
# Total nSV = 678
# [LibSVM].
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2018
# obj = -430.581507, rho = 0.567061
# nSV = 557, nBSV = 474
# Total nSV = 557
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2210
# obj = -433.967617, rho = 0.572367
# nSV = 553, nBSV = 470
# Total nSV = 553
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2243
# obj = -428.994287, rho = 0.557625
# nSV = 551, nBSV = 465
# Total nSV = 551
# .*
# optimization finished, #iter = 1402
# obj = -468.205551, rho = 0.521756
# nSV = 581, nBSV = 514
# Total nSV = 581
# .*.*
# optimization finished, #iter = 2170
# obj = -449.931130, rho = 0.538222
# nSV = 579, nBSV = 493
# Total nSV = 579
# ..*.*
# optimization finished, #iter = 3947
# obj = -542.336741, rho = -0.556944
# nSV = 685, nBSV = 584
# Total nSV = 685
# [LibSVM].*
# optimization finished, #iter = 1878
# obj = -434.314963, rho = 0.516856
# nSV = 550, nBSV = 471
# Total nSV = 550
# .*.*
# optimization finished, #iter = 2796
# obj = -440.467009, rho = 0.565450
# nSV = 563, nBSV = 481
# Total nSV = 563
# .*.*
# optimization finished, #iter = 2101
# obj = -443.275324, rho = 0.556171
# nSV = 565, nBSV = 485
# Total nSV = 565
# .*.*
# optimization finished, #iter = 2429
# obj = -459.530716, rho = 0.512826
# nSV = 584, nBSV = 503
# Total nSV = 584
# .*.*
# optimization finished, #iter = 2159
# obj = -450.328167, rho = 0.506567
# nSV = 580, nBSV = 493
# Total nSV = 580
# ..*.*
# optimization finished, #iter = 3228
# obj = -547.005282, rho = -0.533269
# nSV = 684, nBSV = 589
# Total nSV = 684
# [LibSVM].*
# optimization finished, #iter = 1470
# obj = -428.559839, rho = 0.500204
# nSV = 546, nBSV = 468
# Total nSV = 546
# .*
# optimization finished, #iter = 1888
# obj = -427.735244, rho = 0.569973
# nSV = 548, nBSV = 466
# Total nSV = 548
# .*
# optimization finished, #iter = 1364
# obj = -440.168832, rho = 0.551028
# nSV = 554, nBSV = 477
# Total nSV = 554
# .*.*
# optimization finished, #iter = 2292
# obj = -446.185875, rho = 0.521381
# nSV = 574, nBSV = 488
# Total nSV = 574
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2666
# obj = -452.510224, rho = 0.508898
# nSV = 582, nBSV = 493
# Total nSV = 582
# ..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4061
# obj = -537.626835, rho = -0.548593
# nSV = 678, nBSV = 583
# Total nSV = 678
# [LibSVM].*.*
# optimization finished, #iter = 2137
# obj = -403.465222, rho = 0.542438
# nSV = 523, nBSV = 441
# Total nSV = 523
# .*
# optimization finished, #iter = 1449
# obj = -410.861002, rho = 0.561554
# nSV = 525, nBSV = 456
# Total nSV = 525
# .*.*
# optimization finished, #iter = 2291
# obj = -429.294999, rho = 0.550505
# nSV = 554, nBSV = 472
# Total nSV = 554
# .*
# optimization finished, #iter = 1804
# obj = -435.127113, rho = 0.524385
# nSV = 559, nBSV = 480
# Total nSV = 559
# .*
# optimization finished, #iter = 1988
# obj = -417.873016, rho = 0.503863
# nSV = 537, nBSV = 461
# Total nSV = 537
# ..*
# optimization finished, #iter = 2580
# obj = -510.959148, rho = -0.550986
# nSV = 643, nBSV = 560
# Total nSV = 643
# [LibSVM].*
# optimization finished, #iter = 1893
# obj = -431.512592, rho = 0.559938
# nSV = 545, nBSV = 469
# Total nSV = 545
# ..*
# optimization finished, #iter = 2392
# obj = -463.981328, rho = 0.525844
# nSV = 589, nBSV = 510
# Total nSV = 589
# ..*
# optimization finished, #iter = 2560
# obj = -441.402482, rho = 0.552166
# nSV = 559, nBSV = 487
# Total nSV = 559
# ..*
# optimization finished, #iter = 2604
# obj = -446.628944, rho = 0.587097
# nSV = 570, nBSV = 492
# Total nSV = 570
# ...*
# optimization finished, #iter = 3021
# obj = -431.706214, rho = 0.574238
# nSV = 556, nBSV = 476
# Total nSV = 556
# ..*
# optimization finished, #iter = 2827
# obj = -541.621438, rho = -0.578940
# nSV = 674, nBSV = 591
# Total nSV = 674
# [LibSVM].*
# optimization finished, #iter = 1973
# obj = -430.581507, rho = 0.567111
# nSV = 552, nBSV = 474
# Total nSV = 552
# ..*
# optimization finished, #iter = 2210
# obj = -433.967617, rho = 0.572360
# nSV = 549, nBSV = 470
# Total nSV = 549
# ..*
# optimization finished, #iter = 2086
# obj = -428.994283, rho = 0.557646
# nSV = 550, nBSV = 465
# Total nSV = 550
# .*
# optimization finished, #iter = 1425
# obj = -468.205552, rho = 0.521705
# nSV = 581, nBSV = 515
# Total nSV = 581
# ..*
# optimization finished, #iter = 2173
# obj = -449.931130, rho = 0.538136
# nSV = 572, nBSV = 491
# Total nSV = 572
# ...*
# optimization finished, #iter = 3590
# obj = -542.336748, rho = -0.557010
# nSV = 678, nBSV = 584
# Total nSV = 678
# [LibSVM].*
# optimization finished, #iter = 1878
# obj = -434.314963, rho = 0.516831
# nSV = 544, nBSV = 470
# Total nSV = 544
# ..*
# optimization finished, #iter = 2829
# obj = -440.467014, rho = 0.565368
# nSV = 558, nBSV = 483
# Total nSV = 558
# ..*
# optimization finished, #iter = 2054
# obj = -443.275322, rho = 0.556131
# nSV = 562, nBSV = 484
# Total nSV = 562
# ..*
# optimization finished, #iter = 2421
# obj = -459.530715, rho = 0.512800
# nSV = 581, nBSV = 506
# Total nSV = 581
# ..*
# optimization finished, #iter = 2152
# obj = -450.328166, rho = 0.506540
# nSV = 573, nBSV = 497
# Total nSV = 573
# ..*
# optimization finished, #iter = 2827
# obj = -547.005285, rho = -0.533303
# nSV = 679, nBSV = 589
# Total nSV = 679
# [LibSVM].*
# optimization finished, #iter = 1451
# obj = -428.559838, rho = 0.500190
# nSV = 540, nBSV = 469
# Total nSV = 540
# .*
# optimization finished, #iter = 1856
# obj = -427.735242, rho = 0.569955
# nSV = 544, nBSV = 468
# Total nSV = 544
# .*
# optimization finished, #iter = 1364
# obj = -440.168832, rho = 0.551023
# nSV = 551, nBSV = 478
# Total nSV = 551
# ..*
# optimization finished, #iter = 2206
# obj = -446.185874, rho = 0.521437
# nSV = 570, nBSV = 489
# Total nSV = 570
# ..*
# optimization finished, #iter = 2401
# obj = -452.510225, rho = 0.508857
# nSV = 574, nBSV = 492
# Total nSV = 574
# ..*
# optimization finished, #iter = 2603
# obj = -537.626832, rho = -0.548601
# nSV = 671, nBSV = 582
# Total nSV = 671
# [LibSVM]..*
# optimization finished, #iter = 2092
# obj = -403.465218, rho = 0.542476
# nSV = 521, nBSV = 442
# Total nSV = 521
# .*
# optimization finished, #iter = 1467
# obj = -410.861004, rho = 0.561585
# nSV = 523, nBSV = 458
# Total nSV = 523
# ..*
# optimization finished, #iter = 2314
# obj = -429.295000, rho = 0.550490
# nSV = 552, nBSV = 474
# Total nSV = 552
# .*
# optimization finished, #iter = 1781
# obj = -435.127110, rho = 0.524480
# nSV = 554, nBSV = 480
# Total nSV = 554
# .*
# optimization finished, #iter = 1997
# obj = -417.873016, rho = 0.503843
# nSV = 536, nBSV = 462
# Total nSV = 536
# ..*
# optimization finished, #iter = 2615
# obj = -510.959148, rho = -0.551041
# nSV = 640, nBSV = 561
# Total nSV = 640
# [LibSVM]..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4010
# obj = -541.621442, rho = -0.578932
# nSV = 678, nBSV = 590
# Total nSV = 678
# [LibSVM]..*.*
# optimization finished, #iter = 3947
# obj = -542.336741, rho = -0.556944
# nSV = 685, nBSV = 584
# Total nSV = 685
# [LibSVM]..*.*
# optimization finished, #iter = 3228
# obj = -547.005282, rho = -0.533269
# nSV = 684, nBSV = 589
# Total nSV = 684
# [LibSVM]..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4061
# obj = -537.626835, rho = -0.548593
# nSV = 678, nBSV = 583
# Total nSV = 678
# [LibSVM]..*
# optimization finished, #iter = 2580
# obj = -510.959148, rho = -0.550986
# nSV = 643, nBSV = 560
# Total nSV = 643
# [LibSVM]..*
# optimization finished, #iter = 2827
# obj = -541.621438, rho = -0.578940
# nSV = 674, nBSV = 591
# Total nSV = 674
# [LibSVM]...*
# optimization finished, #iter = 3590
# obj = -542.336748, rho = -0.557010
# nSV = 678, nBSV = 584
# Total nSV = 678
# [LibSVM]..*
# optimization finished, #iter = 2827
# obj = -547.005285, rho = -0.533303
# nSV = 679, nBSV = 589
# Total nSV = 679
# [LibSVM]..*
# optimization finished, #iter = 2603
# obj = -537.626832, rho = -0.548601
# nSV = 671, nBSV = 582
# Total nSV = 671
# [LibSVM]..*
# optimization finished, #iter = 2615
# obj = -510.959148, rho = -0.551041
# nSV = 640, nBSV = 561
# Total nSV = 640
# [LibSVM]..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4010
# obj = -541.621442, rho = -0.578932
# nSV = 678, nBSV = 590
# Total nSV = 678
# [LibSVM]..*.*
# optimization finished, #iter = 3947
# obj = -542.336741, rho = -0.556944
# nSV = 685, nBSV = 584
# Total nSV = 685
# [LibSVM]..*.*
# optimization finished, #iter = 3228
# obj = -547.005282, rho = -0.533269
# nSV = 684, nBSV = 589
# Total nSV = 684
# [LibSVM]..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4061
# obj = -537.626835, rho = -0.548593
# nSV = 678, nBSV = 583
# Total nSV = 678
# [LibSVM]..*
# optimization finished, #iter = 2580
# obj = -510.959148, rho = -0.550986
# nSV = 643, nBSV = 560
# Total nSV = 643
# [LibSVM]..*
# optimization finished, #iter = 2827
# obj = -541.621438, rho = -0.578940
# nSV = 674, nBSV = 591
# Total nSV = 674
# [LibSVM]...*
# optimization finished, #iter = 3590
# obj = -542.336748, rho = -0.557010
# nSV = 678, nBSV = 584
# Total nSV = 678
# [LibSVM]..*
# optimization finished, #iter = 2827
# obj = -547.005285, rho = -0.533303
# nSV = 679, nBSV = 589
# Total nSV = 679
# [LibSVM]..*
# optimization finished, #iter = 2603
# obj = -537.626832, rho = -0.548601
# nSV = 671, nBSV = 582
# Total nSV = 671
# [LibSVM]..*
# optimization finished, #iter = 2615
# obj = -510.959148, rho = -0.551041
# nSV = 640, nBSV = 561
# Total nSV = 640
# [LibSVM]..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4010
# obj = -541.621442, rho = -0.578932
# nSV = 678, nBSV = 590
# Total nSV = 678
# [LibSVM]..*.*
# optimization finished, #iter = 3947
# obj = -542.336741, rho = -0.556944
# nSV = 685, nBSV = 584
# Total nSV = 685
# [LibSVM]..*.*
# optimization finished, #iter = 3228
# obj = -547.005282, rho = -0.533269
# nSV = 684, nBSV = 589
# Total nSV = 684
# [LibSVM]..*.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4061
# obj = -537.626835, rho = -0.548593
# nSV = 678, nBSV = 583
# Total nSV = 678
# [LibSVM]..*
# optimization finished, #iter = 2580
# obj = -510.959148, rho = -0.550986
# nSV = 643, nBSV = 560
# Total nSV = 643
# [LibSVM]..*
# optimization finished, #iter = 2827
# obj = -541.621438, rho = -0.578940
# nSV = 674, nBSV = 591
# Total nSV = 674
# [LibSVM]...*
# optimization finished, #iter = 3590
# obj = -542.336748, rho = -0.557010
# nSV = 678, nBSV = 584
# Total nSV = 678
# [LibSVM]..*
# optimization finished, #iter = 2827
# obj = -547.005285, rho = -0.533303
# nSV = 679, nBSV = 589
# Total nSV = 679
# [LibSVM]..*
# optimization finished, #iter = 2603
# obj = -537.626832, rho = -0.548601
# nSV = 671, nBSV = 582
# Total nSV = 671
# [LibSVM]..*
# optimization finished, #iter = 2615
# obj = -510.959148, rho = -0.551041
# nSV = 640, nBSV = 561
# Total nSV = 640
# [LibSVM]*
# optimization finished, #iter = 271
# obj = -1197.151778, rho = 2.779596
# nSV = 372, nBSV = 367
# Total nSV = 372
# *
# optimization finished, #iter = 346
# obj = -1221.462685, rho = 2.589251
# nSV = 414, nBSV = 408
# Total nSV = 414
# *
# optimization finished, #iter = 276
# obj = -1373.896519, rho = 2.236587
# nSV = 388, nBSV = 382
# Total nSV = 388
# *
# optimization finished, #iter = 325
# obj = -1197.459407, rho = 2.306117
# nSV = 388, nBSV = 383
# Total nSV = 388
# *
# optimization finished, #iter = 339
# obj = -1324.283139, rho = 1.977366
# nSV = 373, nBSV = 368
# Total nSV = 373
# *
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 260
# obj = -935.416038, rho = 1.848101
# nSV = 340, nBSV = 335
# Total nSV = 340
# *
# optimization finished, #iter = 399
# obj = -1345.299339, rho = 2.474301
# nSV = 363, nBSV = 360
# Total nSV = 363
# *
# optimization finished, #iter = 737
# obj = -1352.506765, rho = 2.695967
# nSV = 364, nBSV = 361
# Total nSV = 364
# *
# optimization finished, #iter = 351
# obj = -942.656298, rho = 2.449957
# nSV = 352, nBSV = 347
# Total nSV = 352
# *
# optimization finished, #iter = 247
# obj = -1320.834537, rho = 2.522576
# nSV = 350, nBSV = 345
# Total nSV = 350
# *
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 324
# obj = -1129.711050, rho = 2.955562
# nSV = 363, nBSV = 357
# Total nSV = 363
# *
# optimization finished, #iter = 395
# obj = -1330.431826, rho = 2.367598
# nSV = 358, nBSV = 352
# Total nSV = 358
# *
# optimization finished, #iter = 330
# obj = -1145.481430, rho = 2.695494
# nSV = 358, nBSV = 353
# Total nSV = 358
# *
# optimization finished, #iter = 424
# obj = -1165.188108, rho = 1.881623
# nSV = 358, nBSV = 352
# Total nSV = 358
# *
# optimization finished, #iter = 245
# obj = -1308.004654, rho = 2.318500
# nSV = 341, nBSV = 337
# Total nSV = 341
# *
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 286
# obj = -1341.637623, rho = 2.520671
# nSV = 376, nBSV = 370
# Total nSV = 376
# *
# optimization finished, #iter = 238
# obj = -1332.333383, rho = 2.704651
# nSV = 371, nBSV = 367
# Total nSV = 371
# *
# optimization finished, #iter = 304
# obj = -1425.902522, rho = 2.508795
# nSV = 380, nBSV = 377
# Total nSV = 380
# *
# optimization finished, #iter = 488
# obj = -1077.011021, rho = 2.004716
# nSV = 393, nBSV = 385
# Total nSV = 393
# *
# optimization finished, #iter = 224
# obj = -1329.128773, rho = 2.687224
# nSV = 366, nBSV = 362
# Total nSV = 366
# *
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 256
# obj = -1261.532494, rho = 2.408918
# nSV = 364, nBSV = 360
# Total nSV = 364
# *
# optimization finished, #iter = 325
# obj = -1222.419078, rho = 2.354409
# nSV = 345, nBSV = 340
# Total nSV = 345
# *
# optimization finished, #iter = 241
# obj = -1288.159457, rho = 2.841264
# nSV = 356, nBSV = 351
# Total nSV = 356
# *
# optimization finished, #iter = 286
# obj = -1032.402512, rho = 3.182874
# nSV = 346, nBSV = 341
# Total nSV = 346
# *
# optimization finished, #iter = 240
# obj = -1198.657276, rho = 2.216454
# nSV = 337, nBSV = 331
# Total nSV = 337
# *
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 271
# obj = -1197.151778, rho = 2.779596
# nSV = 372, nBSV = 367
# Total nSV = 372
# *
# optimization finished, #iter = 346
# obj = -1221.462685, rho = 2.589251
# nSV = 414, nBSV = 408
# Total nSV = 414
# *
# optimization finished, #iter = 276
# obj = -1373.896519, rho = 2.236587
# nSV = 388, nBSV = 382
# Total nSV = 388
# *
# optimization finished, #iter = 325
# obj = -1197.459407, rho = 2.306117
# nSV = 388, nBSV = 383
# Total nSV = 388
# *
# optimization finished, #iter = 339
# obj = -1324.283139, rho = 1.977366
# nSV = 373, nBSV = 368
# Total nSV = 373
# *
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 260
# obj = -935.416038, rho = 1.848101
# nSV = 340, nBSV = 335
# Total nSV = 340
# *
# optimization finished, #iter = 399
# obj = -1345.299339, rho = 2.474301
# nSV = 363, nBSV = 360
# Total nSV = 363
# *
# optimization finished, #iter = 737
# obj = -1352.506765, rho = 2.695967
# nSV = 364, nBSV = 361
# Total nSV = 364
# *
# optimization finished, #iter = 351
# obj = -942.656298, rho = 2.449957
# nSV = 352, nBSV = 347
# Total nSV = 352
# *
# optimization finished, #iter = 247
# obj = -1320.834537, rho = 2.522576
# nSV = 350, nBSV = 345
# Total nSV = 350
# *
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 324
# obj = -1129.711050, rho = 2.955562
# nSV = 363, nBSV = 357
# Total nSV = 363
# *
# optimization finished, #iter = 395
# obj = -1330.431826, rho = 2.367598
# nSV = 358, nBSV = 352
# Total nSV = 358
# *
# optimization finished, #iter = 330
# obj = -1145.481430, rho = 2.695494
# nSV = 358, nBSV = 353
# Total nSV = 358
# *
# optimization finished, #iter = 424
# obj = -1165.188108, rho = 1.881623
# nSV = 358, nBSV = 352
# Total nSV = 358
# *
# optimization finished, #iter = 245
# obj = -1308.004654, rho = 2.318500
# nSV = 341, nBSV = 337
# Total nSV = 341
# *
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 286
# obj = -1341.637623, rho = 2.520671
# nSV = 376, nBSV = 370
# Total nSV = 376
# *
# optimization finished, #iter = 238
# obj = -1332.333383, rho = 2.704651
# nSV = 371, nBSV = 367
# Total nSV = 371
# *
# optimization finished, #iter = 304
# obj = -1425.902522, rho = 2.508795
# nSV = 380, nBSV = 377
# Total nSV = 380
# *
# optimization finished, #iter = 488
# obj = -1077.011021, rho = 2.004716
# nSV = 393, nBSV = 385
# Total nSV = 393
# *
# optimization finished, #iter = 224
# obj = -1329.128773, rho = 2.687224
# nSV = 366, nBSV = 362
# Total nSV = 366
# *
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 256
# obj = -1261.532494, rho = 2.408918
# nSV = 364, nBSV = 360
# Total nSV = 364
# *
# optimization finished, #iter = 325
# obj = -1222.419078, rho = 2.354409
# nSV = 345, nBSV = 340
# Total nSV = 345
# *
# optimization finished, #iter = 241
# obj = -1288.159457, rho = 2.841264
# nSV = 356, nBSV = 351
# Total nSV = 356
# *
# optimization finished, #iter = 286
# obj = -1032.402512, rho = 3.182874
# nSV = 346, nBSV = 341
# Total nSV = 346
# *
# optimization finished, #iter = 240
# obj = -1198.657276, rho = 2.216454
# nSV = 337, nBSV = 331
# Total nSV = 337
# *
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 340
# obj = -1299.225957, rho = 1.466834
# nSV = 416, nBSV = 411
# Total nSV = 416
# *
# optimization finished, #iter = 265
# obj = -1300.917324, rho = 2.022469
# nSV = 373, nBSV = 366
# Total nSV = 373
# *
# optimization finished, #iter = 392
# obj = -1424.031055, rho = 2.146411
# nSV = 375, nBSV = 371
# Total nSV = 375
# *
# optimization finished, #iter = 308
# obj = -1311.031025, rho = 1.936460
# nSV = 354, nBSV = 346
# Total nSV = 354
# *
# optimization finished, #iter = 287
# obj = -1217.425143, rho = 2.591428
# nSV = 401, nBSV = 395
# Total nSV = 401
# *
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 357
# obj = -1294.611645, rho = 2.141167
# nSV = 358, nBSV = 353
# Total nSV = 358
# *
# optimization finished, #iter = 492
# obj = -1316.647226, rho = 2.526099
# nSV = 368, nBSV = 363
# Total nSV = 368
# *
# optimization finished, #iter = 284
# obj = -1432.338793, rho = 2.104649
# nSV = 382, nBSV = 377
# Total nSV = 382
# *
# optimization finished, #iter = 383
# obj = -1093.368762, rho = 1.614845
# nSV = 381, nBSV = 375
# Total nSV = 381
# *
# optimization finished, #iter = 422
# obj = -1325.877022, rho = 2.375930
# nSV = 361, nBSV = 356
# Total nSV = 361
# *
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 600
# obj = -1223.569044, rho = 1.676405
# nSV = 355, nBSV = 350
# Total nSV = 355
# *
# optimization finished, #iter = 254
# obj = -1146.410804, rho = 3.090293
# nSV = 345, nBSV = 341
# Total nSV = 345
# *
# optimization finished, #iter = 543
# obj = -1224.956524, rho = 1.232261
# nSV = 366, nBSV = 359
# Total nSV = 366
# *
# optimization finished, #iter = 290
# obj = -1068.618560, rho = 2.317600
# nSV = 337, nBSV = 333
# Total nSV = 337
# *
# optimization finished, #iter = 288
# obj = -1348.507681, rho = 2.061216
# nSV = 368, nBSV = 363
# Total nSV = 368
# *
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 278
# obj = -1255.449468, rho = 2.362437
# nSV = 373, nBSV = 367
# Total nSV = 373
# *
# optimization finished, #iter = 416
# obj = -1310.669066, rho = 2.587202
# nSV = 373, nBSV = 368
# Total nSV = 373
# *
# optimization finished, #iter = 238
# obj = -1413.012013, rho = 2.394603
# nSV = 374, nBSV = 370
# Total nSV = 374
# *
# optimization finished, #iter = 240
# obj = -1230.943163, rho = 2.594776
# nSV = 362, nBSV = 359
# Total nSV = 362
# *
# optimization finished, #iter = 308
# obj = -1378.412785, rho = 3.055481
# nSV = 374, nBSV = 370
# Total nSV = 374
# *
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 273
# obj = -1127.906234, rho = 2.146899
# nSV = 344, nBSV = 337
# Total nSV = 344
# *
# optimization finished, #iter = 735
# obj = -1234.403801, rho = 2.276830
# nSV = 355, nBSV = 349
# Total nSV = 355
# *
# optimization finished, #iter = 389
# obj = -1066.192974, rho = 2.656789
# nSV = 379, nBSV = 374
# Total nSV = 379
# *
# optimization finished, #iter = 507
# obj = -1214.691615, rho = 2.320493
# nSV = 352, nBSV = 348
# Total nSV = 352
# *
# optimization finished, #iter = 399
# obj = -1206.059730, rho = 2.156125
# nSV = 390, nBSV = 385
# Total nSV = 390
# *
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 340
# obj = -1299.225957, rho = 1.466834
# nSV = 416, nBSV = 411
# Total nSV = 416
# *
# optimization finished, #iter = 265
# obj = -1300.917324, rho = 2.022469
# nSV = 373, nBSV = 366
# Total nSV = 373
# *
# optimization finished, #iter = 392
# obj = -1424.031055, rho = 2.146411
# nSV = 375, nBSV = 371
# Total nSV = 375
# *
# optimization finished, #iter = 308
# obj = -1311.031025, rho = 1.936460
# nSV = 354, nBSV = 346
# Total nSV = 354
# *
# optimization finished, #iter = 287
# obj = -1217.425143, rho = 2.591428
# nSV = 401, nBSV = 395
# Total nSV = 401
# *
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 357
# obj = -1294.611645, rho = 2.141167
# nSV = 358, nBSV = 353
# Total nSV = 358
# *
# optimization finished, #iter = 492
# obj = -1316.647226, rho = 2.526099
# nSV = 368, nBSV = 363
# Total nSV = 368
# *
# optimization finished, #iter = 284
# obj = -1432.338793, rho = 2.104649
# nSV = 382, nBSV = 377
# Total nSV = 382
# *
# optimization finished, #iter = 383
# obj = -1093.368762, rho = 1.614845
# nSV = 381, nBSV = 375
# Total nSV = 381
# *
# optimization finished, #iter = 422
# obj = -1325.877022, rho = 2.375930
# nSV = 361, nBSV = 356
# Total nSV = 361
# *
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 600
# obj = -1223.569044, rho = 1.676405
# nSV = 355, nBSV = 350
# Total nSV = 355
# *
# optimization finished, #iter = 254
# obj = -1146.410804, rho = 3.090293
# nSV = 345, nBSV = 341
# Total nSV = 345
# *
# optimization finished, #iter = 543
# obj = -1224.956524, rho = 1.232261
# nSV = 366, nBSV = 359
# Total nSV = 366
# *
# optimization finished, #iter = 290
# obj = -1068.618560, rho = 2.317600
# nSV = 337, nBSV = 333
# Total nSV = 337
# *
# optimization finished, #iter = 288
# obj = -1348.507681, rho = 2.061216
# nSV = 368, nBSV = 363
# Total nSV = 368
# *
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 278
# obj = -1255.449468, rho = 2.362437
# nSV = 373, nBSV = 367
# Total nSV = 373
# *
# optimization finished, #iter = 416
# obj = -1310.669066, rho = 2.587202
# nSV = 373, nBSV = 368
# Total nSV = 373
# *
# optimization finished, #iter = 238
# obj = -1413.012013, rho = 2.394603
# nSV = 374, nBSV = 370
# Total nSV = 374
# *
# optimization finished, #iter = 240
# obj = -1230.943163, rho = 2.594776
# nSV = 362, nBSV = 359
# Total nSV = 362
# *
# optimization finished, #iter = 308
# obj = -1378.412785, rho = 3.055481
# nSV = 374, nBSV = 370
# Total nSV = 374
# *
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 273
# obj = -1127.906234, rho = 2.146899
# nSV = 344, nBSV = 337
# Total nSV = 344
# *
# optimization finished, #iter = 735
# obj = -1234.403801, rho = 2.276830
# nSV = 355, nBSV = 349
# Total nSV = 355
# *
# optimization finished, #iter = 389
# obj = -1066.192974, rho = 2.656789
# nSV = 379, nBSV = 374
# Total nSV = 379
# *
# optimization finished, #iter = 507
# obj = -1214.691615, rho = 2.320493
# nSV = 352, nBSV = 348
# Total nSV = 352
# *
# optimization finished, #iter = 399
# obj = -1206.059730, rho = 2.156125
# nSV = 390, nBSV = 385
# Total nSV = 390
# *
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 285
# obj = -1263.711572, rho = 2.270408
# nSV = 362, nBSV = 357
# Total nSV = 362
# *
# optimization finished, #iter = 312
# obj = -1408.946440, rho = 1.781335
# nSV = 380, nBSV = 375
# Total nSV = 380
# *
# optimization finished, #iter = 337
# obj = -1319.812395, rho = 2.129544
# nSV = 379, nBSV = 373
# Total nSV = 379
# *
# optimization finished, #iter = 254
# obj = -1357.439729, rho = 2.574495
# nSV = 381, nBSV = 378
# Total nSV = 381
# *
# optimization finished, #iter = 474
# obj = -1333.085855, rho = 2.413286
# nSV = 362, nBSV = 358
# Total nSV = 362
# *
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 323
# obj = -865.014848, rho = 2.318351
# nSV = 330, nBSV = 324
# Total nSV = 330
# *
# optimization finished, #iter = 238
# obj = -1373.475701, rho = 2.301547
# nSV = 366, nBSV = 361
# Total nSV = 366
# *
# optimization finished, #iter = 311
# obj = -1298.918490, rho = 2.239194
# nSV = 351, nBSV = 346
# Total nSV = 351
# *
# optimization finished, #iter = 398
# obj = -1323.504940, rho = 2.333091
# nSV = 376, nBSV = 371
# Total nSV = 376
# *
# optimization finished, #iter = 241
# obj = -969.964906, rho = 2.159418
# nSV = 331, nBSV = 326
# Total nSV = 331
# *
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 406
# obj = -1252.721514, rho = 2.345543
# nSV = 339, nBSV = 335
# Total nSV = 339
# *
# optimization finished, #iter = 640
# obj = -1279.779138, rho = 1.820064
# nSV = 358, nBSV = 351
# Total nSV = 358
# *
# optimization finished, #iter = 500
# obj = -1340.880025, rho = 1.887293
# nSV = 361, nBSV = 354
# Total nSV = 361
# *
# optimization finished, #iter = 418
# obj = -1294.643356, rho = 2.389400
# nSV = 365, nBSV = 359
# Total nSV = 365
# *
# optimization finished, #iter = 273
# obj = -1226.826445, rho = 2.581070
# nSV = 363, nBSV = 359
# Total nSV = 363
# *
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 425
# obj = -1314.753488, rho = 2.510623
# nSV = 355, nBSV = 350
# Total nSV = 355
# *
# optimization finished, #iter = 252
# obj = -1312.329019, rho = 2.543037
# nSV = 353, nBSV = 348
# Total nSV = 353
# *
# optimization finished, #iter = 455
# obj = -1367.202721, rho = 2.397395
# nSV = 385, nBSV = 383
# Total nSV = 385
# *
# optimization finished, #iter = 414
# obj = -1351.855138, rho = 2.365140
# nSV = 383, nBSV = 378
# Total nSV = 383
# *
# optimization finished, #iter = 381
# obj = -1153.687973, rho = 3.039677
# nSV = 370, nBSV = 363
# Total nSV = 370
# *
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 663
# obj = -1231.823976, rho = 2.693354
# nSV = 345, nBSV = 340
# Total nSV = 345
# *
# optimization finished, #iter = 409
# obj = -1041.490113, rho = 2.981424
# nSV = 377, nBSV = 372
# Total nSV = 377
# *
# optimization finished, #iter = 424
# obj = -1179.179545, rho = 2.193153
# nSV = 390, nBSV = 386
# Total nSV = 390
# *
# optimization finished, #iter = 362
# obj = -1255.028984, rho = 2.176945
# nSV = 365, nBSV = 360
# Total nSV = 365
# *
# optimization finished, #iter = 283
# obj = -1078.331167, rho = 3.177370
# nSV = 345, nBSV = 340
# Total nSV = 345
# *
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 285
# obj = -1263.711572, rho = 2.270408
# nSV = 362, nBSV = 357
# Total nSV = 362
# *
# optimization finished, #iter = 312
# obj = -1408.946440, rho = 1.781335
# nSV = 380, nBSV = 375
# Total nSV = 380
# *
# optimization finished, #iter = 337
# obj = -1319.812395, rho = 2.129544
# nSV = 379, nBSV = 373
# Total nSV = 379
# *
# optimization finished, #iter = 254
# obj = -1357.439729, rho = 2.574495
# nSV = 381, nBSV = 378
# Total nSV = 381
# *
# optimization finished, #iter = 474
# obj = -1333.085855, rho = 2.413286
# nSV = 362, nBSV = 358
# Total nSV = 362
# *
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 323
# obj = -865.014848, rho = 2.318351
# nSV = 330, nBSV = 324
# Total nSV = 330
# *
# optimization finished, #iter = 238
# obj = -1373.475701, rho = 2.301547
# nSV = 366, nBSV = 361
# Total nSV = 366
# *
# optimization finished, #iter = 311
# obj = -1298.918490, rho = 2.239194
# nSV = 351, nBSV = 346
# Total nSV = 351
# *
# optimization finished, #iter = 398
# obj = -1323.504940, rho = 2.333091
# nSV = 376, nBSV = 371
# Total nSV = 376
# *
# optimization finished, #iter = 241
# obj = -969.964906, rho = 2.159418
# nSV = 331, nBSV = 326
# Total nSV = 331
# *
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 406
# obj = -1252.721514, rho = 2.345543
# nSV = 339, nBSV = 335
# Total nSV = 339
# *
# optimization finished, #iter = 640
# obj = -1279.779138, rho = 1.820064
# nSV = 358, nBSV = 351
# Total nSV = 358
# *
# optimization finished, #iter = 500
# obj = -1340.880025, rho = 1.887293
# nSV = 361, nBSV = 354
# Total nSV = 361
# *
# optimization finished, #iter = 418
# obj = -1294.643356, rho = 2.389400
# nSV = 365, nBSV = 359
# Total nSV = 365
# *
# optimization finished, #iter = 273
# obj = -1226.826445, rho = 2.581070
# nSV = 363, nBSV = 359
# Total nSV = 363
# *
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 425
# obj = -1314.753488, rho = 2.510623
# nSV = 355, nBSV = 350
# Total nSV = 355
# *
# optimization finished, #iter = 252
# obj = -1312.329019, rho = 2.543037
# nSV = 353, nBSV = 348
# Total nSV = 353
# *
# optimization finished, #iter = 455
# obj = -1367.202721, rho = 2.397395
# nSV = 385, nBSV = 383
# Total nSV = 385
# *
# optimization finished, #iter = 414
# obj = -1351.855138, rho = 2.365140
# nSV = 383, nBSV = 378
# Total nSV = 383
# *
# optimization finished, #iter = 381
# obj = -1153.687973, rho = 3.039677
# nSV = 370, nBSV = 363
# Total nSV = 370
# *
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 663
# obj = -1231.823976, rho = 2.693354
# nSV = 345, nBSV = 340
# Total nSV = 345
# *
# optimization finished, #iter = 409
# obj = -1041.490113, rho = 2.981424
# nSV = 377, nBSV = 372
# Total nSV = 377
# *
# optimization finished, #iter = 424
# obj = -1179.179545, rho = 2.193153
# nSV = 390, nBSV = 386
# Total nSV = 390
# *
# optimization finished, #iter = 362
# obj = -1255.028984, rho = 2.176945
# nSV = 365, nBSV = 360
# Total nSV = 365
# *
# optimization finished, #iter = 283
# obj = -1078.331167, rho = 3.177370
# nSV = 345, nBSV = 340
# Total nSV = 345
# *
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# nSV = 454, nBSV = 450
# Total nSV = 454
# [LibSVM]*
# optimization finished, #iter = 527
# obj = -1533.071211, rho = -3.475958
# nSV = 469, nBSV = 463
# Total nSV = 469
# [LibSVM]*
# optimization finished, #iter = 541
# obj = -1971.844666, rho = -2.478755
# nSV = 451, nBSV = 447
# Total nSV = 451
# [LibSVM]*
# optimization finished, #iter = 479
# obj = -1923.582942, rho = -2.790678
# nSV = 440, nBSV = 435
# Total nSV = 440
# [LibSVM]*
# optimization finished, #iter = 529
# obj = -1904.315623, rho = -2.437105
# nSV = 443, nBSV = 438
# Total nSV = 443
# [LibSVM]*
# optimization finished, #iter = 381
# obj = -1934.474192, rho = -3.235554
# ...
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*
# optimization finished, #iter = 829
# obj = -347.287238, rho = 0.919356
# nSV = 467, nBSV = 364
# Total nSV = 467
# *
# optimization finished, #iter = 826
# obj = -340.794481, rho = 0.934049
# nSV = 454, nBSV = 355
# Total nSV = 454
# *
# optimization finished, #iter = 771
# obj = -342.742481, rho = 0.893315
# nSV = 463, nBSV = 359
# Total nSV = 463
# *
# optimization finished, #iter = 696
# obj = -342.418920, rho = 0.970987
# nSV = 451, nBSV = 359
# Total nSV = 451
# *
# optimization finished, #iter = 747
# obj = -350.502025, rho = 0.834403
# nSV = 467, nBSV = 366
# Total nSV = 467
# *.*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011916
# nSV = 558, nBSV = 445
# Total nSV = 558
# [LibSVM]*
# optimization finished, #iter = 742
# obj = -319.547712, rho = 0.798106
# nSV = 442, nBSV = 339
# Total nSV = 442
# *
# optimization finished, #iter = 774
# obj = -323.686378, rho = 0.768953
# nSV = 442, nBSV = 334
# Total nSV = 442
# *
# optimization finished, #iter = 691
# obj = -312.435095, rho = 0.755105
# nSV = 429, nBSV = 327
# Total nSV = 429
# *
# optimization finished, #iter = 751
# obj = -341.642145, rho = 0.854837
# nSV = 458, nBSV = 361
# Total nSV = 458
# *
# optimization finished, #iter = 812
# obj = -335.786963, rho = 0.798651
# nSV = 457, nBSV = 350
# Total nSV = 457
# *
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*
# optimization finished, #iter = 810
# obj = -356.097768, rho = 0.870116
# nSV = 477, nBSV = 375
# Total nSV = 477
# *
# optimization finished, #iter = 708
# obj = -337.609815, rho = 0.820543
# nSV = 454, nBSV = 359
# Total nSV = 454
# *
# optimization finished, #iter = 762
# obj = -350.173735, rho = 0.828346
# nSV = 472, nBSV = 374
# Total nSV = 472
# *
# optimization finished, #iter = 837
# obj = -341.059511, rho = 0.879134
# nSV = 461, nBSV = 350
# Total nSV = 461
# *
# optimization finished, #iter = 830
# obj = -339.445945, rho = 0.891769
# nSV = 461, nBSV = 358
# Total nSV = 461
# .*
# optimization finished, #iter = 1040
# obj = -421.216226, rho = -0.935445
# nSV = 565, nBSV = 448
# Total nSV = 565
# [LibSVM]*
# optimization finished, #iter = 688
# obj = -355.789546, rho = 0.841173
# nSV = 477, nBSV = 379
# Total nSV = 477
# *
# optimization finished, #iter = 705
# obj = -340.036507, rho = 0.754761
# nSV = 448, nBSV = 356
# Total nSV = 448
# *
# optimization finished, #iter = 716
# obj = -365.311427, rho = 0.857691
# nSV = 487, nBSV = 388
# Total nSV = 487
# *
# optimization finished, #iter = 627
# obj = -324.767525, rho = 0.907030
# nSV = 436, nBSV = 341
# Total nSV = 436
# *
# optimization finished, #iter = 782
# obj = -350.354707, rho = 0.813490
# nSV = 476, nBSV = 365
# Total nSV = 476
# *
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 759
# obj = -344.346112, rho = 0.942418
# nSV = 460, nBSV = 363
# Total nSV = 460
# *
# optimization finished, #iter = 740
# obj = -340.965765, rho = 0.849225
# nSV = 448, nBSV = 355
# Total nSV = 448
# *
# optimization finished, #iter = 852
# obj = -358.132179, rho = 0.939395
# nSV = 485, nBSV = 381
# Total nSV = 485
# *
# optimization finished, #iter = 762
# obj = -336.332708, rho = 0.976349
# nSV = 450, nBSV = 352
# Total nSV = 450
# *
# optimization finished, #iter = 854
# obj = -355.191070, rho = 0.892210
# nSV = 470, nBSV = 371
# Total nSV = 470
# *
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*
# optimization finished, #iter = 829
# obj = -347.287238, rho = 0.919356
# nSV = 467, nBSV = 364
# Total nSV = 467
# *
# optimization finished, #iter = 826
# obj = -340.794481, rho = 0.934049
# nSV = 454, nBSV = 355
# Total nSV = 454
# *
# optimization finished, #iter = 771
# obj = -342.742481, rho = 0.893315
# nSV = 463, nBSV = 359
# Total nSV = 463
# *
# optimization finished, #iter = 696
# obj = -342.418920, rho = 0.970987
# nSV = 451, nBSV = 359
# Total nSV = 451
# *
# optimization finished, #iter = 747
# obj = -350.502025, rho = 0.834403
# nSV = 467, nBSV = 366
# Total nSV = 467
# .*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011913
# nSV = 555, nBSV = 445
# Total nSV = 555
# [LibSVM]*
# optimization finished, #iter = 742
# obj = -319.547712, rho = 0.798106
# nSV = 442, nBSV = 339
# Total nSV = 442
# *
# optimization finished, #iter = 774
# obj = -323.686378, rho = 0.768953
# nSV = 442, nBSV = 334
# Total nSV = 442
# *
# optimization finished, #iter = 691
# obj = -312.435095, rho = 0.755105
# nSV = 429, nBSV = 327
# Total nSV = 429
# *
# optimization finished, #iter = 751
# obj = -341.642145, rho = 0.854837
# nSV = 458, nBSV = 361
# Total nSV = 458
# *
# optimization finished, #iter = 812
# obj = -335.786963, rho = 0.798651
# nSV = 457, nBSV = 350
# Total nSV = 457
# *
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*
# optimization finished, #iter = 816
# obj = -344.365091, rho = 0.776413
# nSV = 462, nBSV = 359
# Total nSV = 462
# *
# optimization finished, #iter = 792
# obj = -358.807646, rho = 0.947799
# nSV = 478, nBSV = 371
# Total nSV = 478
# *
# optimization finished, #iter = 948
# obj = -333.648788, rho = 0.816339
# nSV = 459, nBSV = 346
# Total nSV = 459
# *
# optimization finished, #iter = 853
# obj = -347.115395, rho = 0.878019
# nSV = 474, nBSV = 366
# Total nSV = 474
# *
# optimization finished, #iter = 857
# obj = -337.421886, rho = 0.924517
# nSV = 461, nBSV = 356
# Total nSV = 461
# *.*
# optimization finished, #iter = 1063
# obj = -421.216282, rho = -0.935384
# nSV = 567, nBSV = 447
# Total nSV = 567
# [LibSVM]*
# optimization finished, #iter = 774
# obj = -343.683540, rho = 0.783682
# nSV = 460, nBSV = 358
# Total nSV = 460
# *
# optimization finished, #iter = 781
# obj = -346.113608, rho = 0.911501
# nSV = 473, nBSV = 361
# Total nSV = 473
# *
# optimization finished, #iter = 792
# obj = -335.792361, rho = 0.787940
# nSV = 452, nBSV = 352
# Total nSV = 452
# *
# optimization finished, #iter = 726
# obj = -362.212176, rho = 0.853459
# nSV = 474, nBSV = 381
# Total nSV = 474
# *
# optimization finished, #iter = 778
# obj = -350.587971, rho = 0.897364
# nSV = 465, nBSV = 371
# Total nSV = 465
# *
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 768
# obj = -350.855872, rho = 0.866593
# nSV = 457, nBSV = 366
# Total nSV = 457
# *
# optimization finished, #iter = 792
# obj = -339.973883, rho = 0.965089
# nSV = 457, nBSV = 358
# Total nSV = 457
# *
# optimization finished, #iter = 817
# obj = -346.686041, rho = 0.873988
# nSV = 461, nBSV = 359
# Total nSV = 461
# *
# optimization finished, #iter = 742
# obj = -353.406905, rho = 0.923649
# nSV = 469, nBSV = 370
# Total nSV = 469
# *
# optimization finished, #iter = 772
# obj = -348.939663, rho = 1.025553
# nSV = 463, nBSV = 373
# Total nSV = 463
# *
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*
# optimization finished, #iter = 750
# obj = -349.833222, rho = 0.892441
# nSV = 459, nBSV = 371
# Total nSV = 459
# *
# optimization finished, #iter = 714
# obj = -336.129562, rho = 0.903804
# nSV = 451, nBSV = 353
# Total nSV = 451
# *
# optimization finished, #iter = 737
# obj = -342.909901, rho = 0.914353
# nSV = 457, nBSV = 357
# Total nSV = 457
# *
# optimization finished, #iter = 782
# obj = -348.733703, rho = 0.918426
# nSV = 467, nBSV = 362
# Total nSV = 467
# *
# optimization finished, #iter = 859
# obj = -349.320197, rho = 0.961424
# nSV = 462, nBSV = 362
# Total nSV = 462
# *.*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011916
# nSV = 558, nBSV = 445
# Total nSV = 558
# [LibSVM]*
# optimization finished, #iter = 752
# obj = -325.339232, rho = 0.792713
# nSV = 437, nBSV = 339
# Total nSV = 437
# *
# optimization finished, #iter = 715
# obj = -318.566160, rho = 0.765474
# nSV = 441, nBSV = 343
# Total nSV = 441
# *
# optimization finished, #iter = 667
# obj = -331.161742, rho = 0.854974
# nSV = 445, nBSV = 350
# Total nSV = 445
# *
# optimization finished, #iter = 832
# obj = -334.567145, rho = 0.786085
# nSV = 463, nBSV = 352
# Total nSV = 463
# *
# optimization finished, #iter = 694
# obj = -324.418412, rho = 0.739720
# nSV = 444, nBSV = 344
# Total nSV = 444
# *
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*
# optimization finished, #iter = 816
# obj = -344.365091, rho = 0.776413
# nSV = 462, nBSV = 359
# Total nSV = 462
# *
# optimization finished, #iter = 792
# obj = -358.807646, rho = 0.947799
# nSV = 478, nBSV = 371
# Total nSV = 478
# *
# optimization finished, #iter = 948
# obj = -333.648788, rho = 0.816339
# nSV = 459, nBSV = 346
# Total nSV = 459
# *
# optimization finished, #iter = 853
# obj = -347.115395, rho = 0.878019
# nSV = 474, nBSV = 366
# Total nSV = 474
# *
# optimization finished, #iter = 857
# obj = -337.421886, rho = 0.924517
# nSV = 461, nBSV = 356
# Total nSV = 461
# .*
# optimization finished, #iter = 1040
# obj = -421.216226, rho = -0.935445
# nSV = 565, nBSV = 448
# Total nSV = 565
# [LibSVM]*
# optimization finished, #iter = 774
# obj = -343.683540, rho = 0.783682
# nSV = 460, nBSV = 358
# Total nSV = 460
# *
# optimization finished, #iter = 781
# obj = -346.113608, rho = 0.911501
# nSV = 473, nBSV = 361
# Total nSV = 473
# *
# optimization finished, #iter = 792
# obj = -335.792361, rho = 0.787940
# nSV = 452, nBSV = 352
# Total nSV = 452
# *
# optimization finished, #iter = 726
# obj = -362.212176, rho = 0.853459
# nSV = 474, nBSV = 381
# Total nSV = 474
# *
# optimization finished, #iter = 778
# obj = -350.587971, rho = 0.897364
# nSV = 465, nBSV = 371
# Total nSV = 465
# *
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 768
# obj = -350.855872, rho = 0.866593
# nSV = 457, nBSV = 366
# Total nSV = 457
# *
# optimization finished, #iter = 792
# obj = -339.973883, rho = 0.965089
# nSV = 457, nBSV = 358
# Total nSV = 457
# *
# optimization finished, #iter = 817
# obj = -346.686041, rho = 0.873988
# nSV = 461, nBSV = 359
# Total nSV = 461
# *
# optimization finished, #iter = 742
# obj = -353.406905, rho = 0.923649
# nSV = 469, nBSV = 370
# Total nSV = 469
# *
# optimization finished, #iter = 772
# obj = -348.939663, rho = 1.025553
# nSV = 463, nBSV = 373
# Total nSV = 463
# *
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*
# optimization finished, #iter = 750
# obj = -349.833222, rho = 0.892441
# nSV = 459, nBSV = 371
# Total nSV = 459
# *
# optimization finished, #iter = 714
# obj = -336.129562, rho = 0.903804
# nSV = 451, nBSV = 353
# Total nSV = 451
# *
# optimization finished, #iter = 737
# obj = -342.909901, rho = 0.914353
# nSV = 457, nBSV = 357
# Total nSV = 457
# *
# optimization finished, #iter = 782
# obj = -348.733703, rho = 0.918426
# nSV = 467, nBSV = 362
# Total nSV = 467
# *
# optimization finished, #iter = 859
# obj = -349.320197, rho = 0.961424
# nSV = 462, nBSV = 362
# Total nSV = 462
# .*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011913
# nSV = 555, nBSV = 445
# Total nSV = 555
# [LibSVM]*
# optimization finished, #iter = 752
# obj = -325.339232, rho = 0.792713
# nSV = 437, nBSV = 339
# Total nSV = 437
# *
# optimization finished, #iter = 715
# obj = -318.566160, rho = 0.765474
# nSV = 441, nBSV = 343
# Total nSV = 441
# *
# optimization finished, #iter = 667
# obj = -331.161742, rho = 0.854974
# nSV = 445, nBSV = 350
# Total nSV = 445
# *
# optimization finished, #iter = 832
# obj = -334.567145, rho = 0.786085
# nSV = 463, nBSV = 352
# Total nSV = 463
# *
# optimization finished, #iter = 694
# obj = -324.418412, rho = 0.739720
# nSV = 444, nBSV = 344
# Total nSV = 444
# *
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*.*
# optimization finished, #iter = 1063
# obj = -421.216282, rho = -0.935384
# nSV = 567, nBSV = 447
# Total nSV = 567
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*.*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011916
# nSV = 558, nBSV = 445
# Total nSV = 558
# [LibSVM]*
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM].*
# optimization finished, #iter = 1040
# obj = -421.216226, rho = -0.935445
# nSV = 565, nBSV = 448
# Total nSV = 565
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM].*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011913
# nSV = 555, nBSV = 445
# Total nSV = 555
# [LibSVM]*
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*.*
# optimization finished, #iter = 1063
# obj = -421.216282, rho = -0.935384
# nSV = 567, nBSV = 447
# Total nSV = 567
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*.*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011916
# nSV = 558, nBSV = 445
# Total nSV = 558
# [LibSVM]*
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM].*
# optimization finished, #iter = 1040
# obj = -421.216226, rho = -0.935445
# nSV = 565, nBSV = 448
# Total nSV = 565
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM].*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011913
# nSV = 555, nBSV = 445
# Total nSV = 555
# [LibSVM]*
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*.*
# optimization finished, #iter = 1063
# obj = -421.216282, rho = -0.935384
# nSV = 567, nBSV = 447
# Total nSV = 567
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM]*.*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011916
# nSV = 558, nBSV = 445
# Total nSV = 558
# [LibSVM]*
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM].*
# optimization finished, #iter = 1040
# obj = -421.216226, rho = -0.935445
# nSV = 565, nBSV = 448
# Total nSV = 565
# [LibSVM]*
# optimization finished, #iter = 884
# obj = -426.914673, rho = -0.913557
# nSV = 557, nBSV = 452
# Total nSV = 557
# [LibSVM]*
# optimization finished, #iter = 932
# obj = -425.991957, rho = -1.015477
# nSV = 554, nBSV = 444
# Total nSV = 554
# [LibSVM].*
# optimization finished, #iter = 1078
# obj = -422.565205, rho = -1.011913
# nSV = 555, nBSV = 445
# Total nSV = 555
# [LibSVM]*
# optimization finished, #iter = 968
# obj = -399.331717, rho = -0.830938
# nSV = 532, nBSV = 423
# Total nSV = 532
# [LibSVM]*.*
# optimization finished, #iter = 1044
# obj = -418.666875, rho = 0.856321
# nSV = 559, nBSV = 433
# Total nSV = 559
# *
# optimization finished, #iter = 887
# obj = -416.869854, rho = 0.917325
# nSV = 550, nBSV = 441
# Total nSV = 550
# *
# optimization finished, #iter = 920
# obj = -416.372954, rho = 0.986566
# nSV = 541, nBSV = 430
# Total nSV = 541
# *
# optimization finished, #iter = 951
# obj = -418.203263, rho = 0.971915
# nSV = 555, nBSV = 442
# Total nSV = 555
# *.*
# optimization finished, #iter = 1086
# obj = -428.267662, rho = 0.977845
# nSV = 572, nBSV = 445
# Total nSV = 572
# *.*
# optimization finished, #iter = 1145
# obj = -512.800731, rho = -1.019124
# nSV = 673, nBSV = 548
# Total nSV = 673
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'decision_function_shape': ['ovo', 'ovr'],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'sigmoid', 'rbf'],
#                          'probability': [True, False],
#                          'random_state': [21, 42, 104],
#                          'shrinking': [True, False], 'verbose': [True, False]})

# %%
GSCV.best_params_
# Out:
# {'decision_function_shape': 'ovo',
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'verbose': True}

# %%
Final_Model = SVC(decision_function_shape='ovo', gamma='scale', kernel='rbf', probability=True, random_state=21,
                 shrinking=True, verbose=True)
Classifier = Final_Model.fit(X_train, Y_train)
fmod_pred = Final_Model.predict(X_test)
fmod_acc = (accuracy_score(Y_test, fmod_pred))*100
print("Accuracy score for the Best Model is:", fmod_acc)
# Out:
# [LibSVM]*.*
# optimization finished, #iter = 1044
# obj = -418.666875, rho = 0.856321
# nSV = 559, nBSV = 433
# Total nSV = 559
# *
# optimization finished, #iter = 887
# obj = -416.869854, rho = 0.917325
# nSV = 550, nBSV = 441
# Total nSV = 550
# *
# optimization finished, #iter = 920
# obj = -416.372954, rho = 0.986566
# nSV = 541, nBSV = 430
# Total nSV = 541
# *
# optimization finished, #iter = 951
# obj = -418.203263, rho = 0.971915
# nSV = 555, nBSV = 442
# Total nSV = 555
# *.*
# optimization finished, #iter = 1086
# obj = -428.267662, rho = 0.977845
# nSV = 572, nBSV = 445
# Total nSV = 572
# *.*
# optimization finished, #iter = 1145
# obj = -512.800731, rho = -1.019124
# nSV = 673, nBSV = 548
# Total nSV = 673
# Accuracy score for the Best Model is: 92.94871794871796

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import RocCurveDisplay

# %%
disp = metrics.RocCurveDisplay.from_estimator(Final_Model, X_test, Y_test)
disp.figure_.suptitle("ROC Curve")
plt.show()

# %%
import joblib

# %%
joblib.dump(Final_Model, "Perfect_Wine_Quality_Analysis.pkl")
# Out:
# ['Perfect_Wine_Quality_Analysis.pkl']
