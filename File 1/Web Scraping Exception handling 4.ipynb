# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import ElementNotInteractableException
import requests
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Q1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)Rank B) Name C) Artist D) Upload date E) Views

# %%
# Activating the chrome browser
driver = webdriver.Chrome()

# %%
# Opening  webpage
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)
time.sleep(2)

# %%
# Extracting Rank
Rank =[]
try:
    rank=driver.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[0]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')
except StaleElementReferenceException:
    Rank.append('NA')

# %%
# Extracting Names
Name =[]
try:
    name=driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in name:
        Name.append(i.text)
except NoSuchElementExceptionhElementException:
    Name.append('NA')
except StaleElementReferenceException:
    Name.append('NA')

# %%
# Extracting Artist
Artist =[]
try:
    artist=driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementExceptionhElementException:
    Artist.append('NA')
except StaleElementReferenceException:
    Artist.append('NA')

# %%
# Extracting Upload date
Upload_Dates=[]
try:
    upload_date=driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"][1]/tbody/tr/td[4]')
    for i in upload_date:
        Upload_Dates.append(i.text)
except NoSuchElementExceptionhElementException:
    Upload_Dates.append('NA')
except StaleElementReferenceException:
    Upload_Dates.append('NA')

# %%
# Extracting Views
View=[]
try:
    views=driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"][1]/tbody/tr/td[3]')
    for i in views:
        View.append(i.text)
except NoSuchElementExceptionhElementException:
    View.append('NA')
except StaleElementReferenceException:
    View.append('NA')

# %%
len(Name),len(Artist),len(View),len(Upload_Dates)
# Out:
# (30, 30, 30, 30)

# %%
Youtube=pd.DataFrame({'Video Name':Name,'Uploader':Artist,'Views (in Billons)':View,'Upload Date':Upload_Dates})
Youtube
# Out:
#                                          Video Name  \
# 0                             "Baby Shark Dance"[6]
# 1                                    "Despacito"[9]
# 2                        "Johny Johny Yes Papa"[17]
# 3                                   "Bath Song"[18]
# 4                                "Shape of You"[19]
# 5                               "See You Again"[22]
# 6                           "Wheels on the Bus"[27]
# 7                 "Phonics Song with Two Words"[28]
# 8                                 "Uptown Funk"[29]
# 9   "Learning Colors – Colorful Eggs on a Farm"[30]
# 10                              "Gangnam Style"[31]
# 11   "Masha and the Bear – Recipe for Disaster"[36]
# 12                             "Dame Tu Cosita"[37]
# 13                                     "Axel F"[38]
# 14                                      "Sugar"[39]
# 15                             "Counting Stars"[40]
# 16                                       "Roar"[41]
# ...

# %%
driver.close()

# %% [markdown]
# ### Q2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# #### You need to find following details: A) Series B) Place C) Date D) Time

# %%
# Activating the chrome browser
driver=webdriver.Chrome()

# %%
# open url
Url='https://www.bcci.tv/'
driver.get(Url)

# %%
# Opening fixtures
fixtures=driver.find_element(By.XPATH, '//div[@class="imw-tabs international-tabs"]/a[2]')
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))

# %%
Series_Name=[]

sn=driver.find_elements(By.XPATH, '//h5[@class="match-tournament-name ng-binding"]')

for i in sn:
    Series_Name.append(i.text)
len(Series_Name)
# Out:
# 14

# %%
# Scraping Place
Place=[]

plc=driver.find_elements(By.XPATH, '//div[@class="match-place ng-scope"]')

for i in plc:
    Place.append(i.text)
len(Place)
# Out:
# 14

# %%
Date=[]

dt=driver.find_elements(By.XPATH, '//div[@class="match-dates ng-binding"]')

for i in dt:
    Date.append(i.text)
len(Date)
# Out:
# 14

# %%
Time=[]

tm=driver.find_elements(By.XPATH, '//div[@class="match-time no-margin ng-binding"]')

for i in tm:
    Time.append(i.text)
Time
len(Time)
# Out:
# 14

# %%
Cricket=pd.DataFrame({'Tournament':Series_Name,'Venue':Place,'Date':Date,'Time':Time})
Cricket
# Out:
#                                Tournament  \
# 0   AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 1   AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 2      INDIA TOUR OF SOUTH AFRICA 2023-24
# 3   AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 4   AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 5   AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 6       AFGHANISTAN TOUR OF INDIA 2023-24
# 7       AFGHANISTAN TOUR OF INDIA 2023-24
# 8       AFGHANISTAN TOUR OF INDIA 2023-24
# 9           ENGLAND TOUR OF INDIA 2023-24
# 10          ENGLAND TOUR OF INDIA 2023-24
# 11          ENGLAND TOUR OF INDIA 2023-24
# 12          ENGLAND TOUR OF INDIA 2023-24
# 13          ENGLAND TOUR OF INDIA 2023-24
#
#                                                 Venue               Date  \
# 0                            Wankhede Stadium, Mumbai  30 DECEMBER, 2023
# 1                            Wankhede Stadium, Mumbai    2 JANUARY, 2024
# 2                                 Newlands, Cape Town    3 JANUARY, 2024
# ...

# %%
driver.close()

# %% [markdown]
# ### Q3. Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/ You have to find following details: A) Rank B) State C) GSDP(18-19)- at current prices D) GSDP(19-20)- at current prices E) Share(18-19) F) GDP ($ billion)

# %%
# Activating the chrome browser
driver=webdriver.Chrome()
time.sleep(1)

# Opening webpage
url='https://www.statisticstimes.com/'
driver.get(url)
time.sleep(1)

# %%
# Clicking on India under ecomony section
India=driver.find_element(By.XPATH, '//div[@class="dropdown"][2]/div/a[3]')
try:
    India.click()
except ElementNotInteractableException:
    driver.get(India.get_attribute('href'))

# %%
# Clicking Indian State GDP
state = driver.find_element(By.XPATH, '//ul[@style="list-style-type:none;margin-left:20px;"]/li[1]/a')
try:
    state.click()
except ElementNotInteractableException:
    driver.get(state.get_attribute('href'))
time.sleep(2)

# %%
# Extracting Rank
Rank =[]
try:
    rank=driver.find_elements(By.XPATH, '//table[@id="table_id"]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('NA')

# %%
# Extracting state name
State =[]
try:
    state=driver.find_elements(By.XPATH, '//table[@id="table_id"]/tbody/tr/td[2]')
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('NA')

# %%
# Extracting GDSP 19-20
GSDP1 =[]
try:
    gdsp_19_20=driver.find_elements(By.XPATH, '//table[@id="table_id"]/tbody/tr/td[3]')
    for i in gdsp_19_20:
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append('NA')

# %%
# Extracting GDSP 18-19
GSDP2=[]
try:
    gdsp_18_19=driver.find_elements(By.XPATH, '//table[@id="table_id"]/tbody/tr/td[4]')
    for i in gdsp_18_19:
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append('NA')

# %%
# Extracting share
Share=[]
try:
    share=driver.find_elements(By.XPATH, '//table[@id="table_id"]/tbody/tr/td[5]')
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('NA')

# %%
# Extracting GDP
GDP=[]
try:
    gdp=driver.find_elements(By.XPATH, '//table[@id="table_id"]/tbody/tr/td[6]')
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('NA')

# %%
State_GDP=pd.DataFrame({'Rank':Rank,'State':State,'GDSP 19-20':GSDP1,'GDSP 18-19':GSDP2,
                            'Share':Share,'GDP (in Billions)':GDP})
State_GDP
# Out:
#    Rank                      State GDSP 19-20 GDSP 18-19   Share  \
# 0     1                Maharashtra          -  3,108,022  13.24%
# 1     2                 Tamil Nadu  2,364,514  2,071,286   8.82%
# 2     3              Uttar Pradesh  2,257,575  1,974,532   8.41%
# 3     4                  Karnataka  2,241,368  1,962,725   8.36%
# 4     5                    Gujarat          -  1,937,066   8.25%
# 5     6                West Bengal  1,554,992  1,363,926   5.81%
# 6     7                  Rajasthan  1,413,620  1,218,193   5.19%
# 7     8             Madhya Pradesh  1,322,821  1,136,137   4.84%
# 8     9             Andhra Pradesh  1,317,728  1,133,837   4.83%
# 9    10                  Telangana  1,313,391  1,128,907   4.81%
# 10   11                     Kerala          -    932,470   3.97%
# 11   12                      Delhi  1,043,759    904,642   3.85%
# 12   13                    Haryana    994,154    870,665   3.71%
# ...

# %%
driver.close()

# %% [markdown]
# ### Q4. Scrape the details of trending repositories on Github.com. Url = https://github.com/ You have to find the following details: A) Repository title B) Repository description C) Contributors count D) Language used

# %%
# Opening webdriver
driver=webdriver.Chrome()
time.sleep(1)

# Opening github
url='https://github.com/'
driver.get(url)
time.sleep(1)

# %%
ex=driver.find_element(By.XPATH, "//ul[@class='d-lg-flex list-style-none']/li[4]").click()

# %%
td=driver.find_element(By.XPATH, '//a[@class="js-selected-navigation-item selected d-inline-block py-2 py-md-3 mr-3 mr-md-4 no-underline subnav-link"]')
td.click()

# %%
#Scraping Repositority Title
Title=[]
try:
    title=driver.find_elements(By.XPATH, '//h2[@class="h3 lh-condensed"]/a')
    for i in title:
        Title.append(i.text)
except NoSuchElementException:
    Title.append('NA')

# %%
len(Title)
# Out:
# 25

# %%
# Scraping Description
Description=[]
try:
    description=driver.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]')
    for i in description:
        Description.append(i.text)
except NoSuchElementException:
    Description.append('NA')

# %%
len(Description)
# Out:
# 25

# %%
#Scraping Contributor count
Count =[]
try:
    count=driver.find_elements(By.XPATH, '//div[@class="f6 color-fg-muted mt-2"]/a[2]')
    for i in count:
        Count.append(i.text)
except NoSuchElementException:
    Count.append('NA')

# %%
len(Count)
# Out:
# 25

# %%
#Scraping Language
Language =[]
try:
    language=driver.find_elements(By.XPATH, '//div[@class="f6 color-fg-muted mt-2"]/span[1]')
    for i in language:
        Language.append(i.text)
except NoSuctElementException:
    Language.append('NA')

# %%
len(Language)
# Out:
# 25

# %%
GH=pd.DataFrame({'Title':Title,'Description':Description, 'Contributors_count':Count,'Language_used':Language})
GH
# Out:
#                                       Title  \
# 0                   Frooodle / Stirling-PDF
# 1                       BartoszJarocki / cv
# 2                        nomic-ai / gpt4all
# 3                           nodejs / undici
# 4                            shadcn-ui / ui
# 5                             apache / hudi
# 6                   microsoft / promptbench
# 7                           Hillobar / Rope
# 8          karanpratapsingh / system-design
# 9   DopplerHQ / awesome-interview-questions
# 10                    movie-web / movie-web
# 11               HuolalaTech / page-spy-web
# 12                         THUDM / ChatGLM3
# 13                   d3george / slash-admin
# 14              iusztinpaul / hands-on-llms
# 15          cumulo-autumn / StreamDiffusion
# 16                    xinghaochen / TinySAM
# 17            Flipper-XFW / Xtreme-Firmware
# 18                          unocss / unocss
# 19            alibaba-damo-academy / FunASR
# ...

# %%
driver.close()

# %% [markdown]
# ### Q5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the following details: A) Song name B) Artist name C) Last week rank D) Peak rank E) Weeks on board

# %%
#Opening webdriver
driver=webdriver.Chrome()
time.sleep(1)

# %%
# Opening billboard webpage
url='https://www.billboard.com/'
driver.get(url)
time.sleep(1)

# %%
menu=driver.find_element(By.XPATH, '/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button')
menu.click()

# %%
chart=driver.find_element(By.XPATH, '//a[@class="c-link  lrv-a-unstyle-link a-font-primary-bold lrv-u-font-size-28@desktop-xl lrv-u-font-size-18 lrv-u-color-grey:hover u-padding-a-1@desktop-max lrv-u-padding-b-050"]')
chart.click()

# %%
# Click on hot 100 option
hot_100=driver.find_element(By.XPATH, '//a[@class="c-label__link lrv-u-color-brand-primary u-color-black@mobile-max a-font-primary-bold lrv-u-font-size-32 u-whitespace-nowrap@tablet"]')
try:
    hot_100.click()
except ElementNotInteractableException:
    driver.get(hot_100.get_attribute('href'))
time.sleep(2)

# %%
# Scraping Song Name
Songs =[]
try:
    song=driver.find_elements(By.XPATH, '//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li/h3')
    for i in song:
        Songs.append(i.text)
except NoSuchElementException:
    Songs.append('NA')

# %%
# Scraping Artist Name
Artist =[]
try:
    an=driver.find_elements(By.XPATH, '//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
    for i in an:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append('NA')

# %%
try:
    artist=driver.find_elements(By.XPATH, '//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append('NA')

# %%
# Scraping Song last week rank
Last_Week_Rank=[]
try:
    last_rank=driver.find_elements(By.XPATH, '//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[4]')
    for i in last_rank:
        Last_Week_Rank.append(i.text)
except NoSuchElementException:
    Last_Week_Rank.append('NA')

# %%
# Scraping Song peak rank
Peak_rank =[]
try:
    peak=driver.find_elements(By.XPATH, '//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[5]')
    for i in peak:
        Peak_rank.append(i.text)
except NoSuchElementException:
    Peak_rank.append('NA')

# %%
#Scraping Song Week on board
Weeks =[]
try:
    weeks=driver.find_elements(By.XPATH, '//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li[6]')
    for i in weeks:
        Weeks.append(i.text)
except NoSuchElementException:
    Weeks.append('NA')

# %%
Hot100=pd.DataFrame({'Song_Name':Songs, 'Artist_Name':Artist, 'Last_Week_Rank':Last_Week_Rank, 'Peak_Rank':Peak_rank, 'Weeks_On_Chart':Weeks})
Hot100
# Out:
#                             Song_Name                             Artist_Name  \
# 0     All I Want For Christmas Is You                            Mariah Carey
# 1   Rockin' Around The Christmas Tree                              Brenda Lee
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                  Winter Wonderland                                   Chloe
# 96                  Run For The Hills                              Tate McRae
# 97                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 98                       Great Gatsby                                Rod Wave
# 99                   One Of The Girls     The Weeknd, JENNIE & Lily Rose Depp
#
# ...

# %%
driver.close()

# %% [markdown]
# ### Q6. Scrape the details of Highest selling novels. Url - https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
# A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
#Opening Chrome
driver=webdriver.Chrome()
time.sleep(1)

# %%
#Opening webpage
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)
time.sleep(1)

# %%
# Scraping Book name
Book_Name=[]
try:
    book=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[2]')
    for i in book:
        Book_Name.append(i.text)
except NoSuchElementException:
    Book_Name.append('NA')

# %%
# Scraping Author name
Author_Name=[]
try:
    author=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[3]')
    for i in author:
        Author_Name.append(i.text)
except NoSuchElementException:
    Author_Name.append('NA')

# %%
# Scraping Volumes sold
Volumes_Sold=[]
try:
    sold=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[4]')
    for i in sold:
        Volumes_Sold.append(i.text)
except NoSuchElementException:
    Volumes_Sold.append('NA')

# %%
# Scraping publisher
Publisher=[]
try:
    publisher=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[5]')
    for i in publisher:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('NA')

# %%
# Scraping Genre
Genre=[]
try:
    genre=driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[6]')
    for i in genre:
        Genre.append(i.text)
except NoSuchElementException:
    Genre.append('NA')

# %%
Best_Books=pd.DataFrame({'Book Title':Book_Name,'Author Name':Author_Name,'Volumes sold':Volumes_Sold,'Publisher':Publisher,'Genre':Genre})
Best_Books
# Out:
#                                            Book Title       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# ### Q7. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:
# #### A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
#Open webdriver
driver=webdriver.Chrome()
time.sleep(1)

# %%
# Opening imdb webpage
url='https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(1)

# %% [markdown]
# ## URL NOT WORKING

# %%
driver.close()

# %% [markdown]
# ### Q8. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/ You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.common.exceptions import ElementNotInteractableException
import requests
from selenium.webdriver.common.by import By

# %%
#Open webdriver
driver=webdriver.Chrome()
time.sleep(1)

# %%
# Opening webpage
url='https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(1)

# %%
# Clicking on all datasets links
dataset=driver.find_element(By.XPATH, '//a[@href="/datasets"]')
dataset.click()
time.sleep(1)

# %%
Namez=[]

# %%
# Scraping DataSet Name
start=0
end=662
for page in range(start,end):
    name=driver.find_elements(By.XPATH, '//h2[@class="truncate text-primary"]/a')
    for i in name:
        Namez.append(i.text)
    next_button=driver.find_element(By.XPATH, '/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_button.click()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[176], line 9
#       7     Namez.append(i.text)
#       8 next_button=driver.find_element(By.XPATH, '/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
# ----> 9 next_button.click()
#      10 time.sleep(3)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# ...

# %%
len(Namez)
# Out:
# 663

# %%
Dt=[]

# %%
start=0
end=664
for page in range(start,end):
    dt=driver.find_elements(By.XPATH, '//div[@class="col-span-3 flex items-center gap-2"][2]/span')
    for i in dt:
        Dt.append(i.text)
    next_button=driver.find_element(By.XPATH, '/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
    next_button.click()
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[206], line 8
#       6     Dt.append(i.text)
#       7 next_button=driver.find_element(By.XPATH, '/html/body/div/div[1]/div[1]/main/div/div[2]/div[3]/div/button[2]')
# ----> 8 next_button.click()
#       9 time.sleep(3)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# ...

# %%
len(Dt)
# Out:
# 659

# %% [markdown]
# ### LINK IS CRASHING SHOWING ERROR 500

# %%
driver.close()
